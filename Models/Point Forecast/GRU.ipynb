# %%
"""
Carbon Price Forecasting with PyTorch GRU
- Hyperparameters tuned via Optuna: lookback, n_layers, hidden_size, learning_rate, batch_size
- Proper scaling (train-only during tuning; train+val for final model)
- Time split: Train=2021-01-01..2023-12-31 (last 10% of that for val); Test=2024-01-01..2024-12-31
- Rolling (recursive) forecast on the 2024 test set

Requirements: pip install optuna torch scikit-learn matplotlib pandas
"""

import os
import math
import json
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import optuna

# -------------------- Config --------------------
RANDOM_STATE = 42
CSV_PATH = "Carbon_Emissions_Futures_2021_Onwards.csv"  # <--- change if needed
DATE_COL = "Date"
TARGET_COL = "Price"

# Reproducibility
random.seed(RANDOM_STATE)
np.random.seed(RANDOM_STATE)
torch.manual_seed(RANDOM_STATE)

# -------------------- Data utils --------------------
def _parse_volume(v):
    if pd.isna(v):
        return np.nan
    if isinstance(v, (int, float)):
        return float(v)
    s = str(v).strip().replace(",", "")
    if s.endswith(("K","k")):
        return float(s[:-1]) * 1_000
    if s.endswith(("M","m")):
        return float(s[:-1]) * 1_000_000
    return float(s)


def clean_dataframe(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    df.rename(columns={"Vol.": "Volume", "Change %": "ChangePct"}, inplace=True)
    df[DATE_COL] = pd.to_datetime(df[DATE_COL], dayfirst=True, errors='coerce')
    for col in ["Price", "Open", "High", "Low"]:
        df[col] = pd.to_numeric(df[col], errors='coerce')
    if "Volume" in df:
        df["Volume"] = df["Volume"].apply(_parse_volume)
    if "ChangePct" in df:
        df["ChangePct"] = pd.to_numeric(df["ChangePct"].astype(str).str.replace('%',''), errors='coerce') / 100.0
    df = df.dropna(subset=[DATE_COL]).sort_values(DATE_COL).reset_index(drop=True)
    return df


def train_val_test_split(df: pd.DataFrame):
    train_mask = (df[DATE_COL] >= '2021-01-01') & (df[DATE_COL] <= '2023-12-31')
    test_mask  = (df[DATE_COL] >= '2024-01-01') & (df[DATE_COL] <= '2024-12-31')
    df_train_full = df.loc[train_mask].copy()
    df_test = df.loc[test_mask].copy()
    split_idx = int(len(df_train_full) * 0.9)
    return df_train_full.iloc[:split_idx], df_train_full.iloc[split_idx:], df_test


def create_sequences(series_2d: np.ndarray, lookback: int):
    """series_2d shape: (N, 1). Returns X: (N-lookback, lookback, 1), y: (N-lookback,).
    """
    X, y = [], []
    for i in range(lookback, len(series_2d)):
        X.append(series_2d[i-lookback:i])
        y.append(series_2d[i, 0])
    return np.asarray(X, dtype=np.float32), np.asarray(y, dtype=np.float32)


class SeqDataset(Dataset):
    def __init__(self, X: np.ndarray, y: np.ndarray):
        self.X = X
        self.y = y
    def __len__(self):
        return len(self.X)
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]


# -------------------- Model (GRU) --------------------
class GRURegressor(nn.Module):
    def __init__(self, input_size: int, hidden_size: int, num_layers: int):
        super().__init__()
        # Use nn.GRU for Gated Recurrent Unit
        self.gru = nn.GRU(input_size=input_size, hidden_size=hidden_size, num_layers=num_layers, batch_first=True)
        self.head = nn.Linear(hidden_size, 1)
    def forward(self, x):  # x: (B, T, F)
        # nn.GRU returns (output, h_n), we only need the output
        out, _ = self.gru(x)
        last = out[:, -1, :] # Use the output from the last time step
        return self.head(last).squeeze(-1)


# -------------------- Metrics --------------------
def evaluate_metrics(y_true, y_pred):
    mse = mean_squared_error(y_true, y_pred)
    rmse = math.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    mape = np.mean(np.abs((y_true - y_pred) / np.clip(np.abs(y_true), 1e-8, None))) * 100
    r2 = r2_score(y_true, y_pred)
    return {"MSE": mse, "RMSE": rmse, "MAE": mae, "MAPE%": mape, "R2": r2}


# -------------------- Training loop --------------------
def train_epoch(model, loader, criterion, optimizer, device):
    model.train()
    total = 0.0
    for xb, yb in loader:
        xb = xb.to(device)
        yb = yb.to(device)
        optimizer.zero_grad()
        pred = model(xb)
        loss = criterion(pred, yb)
        loss.backward()
        optimizer.step()
        total += loss.item() * xb.size(0)
    return total / len(loader.dataset)


def eval_epoch(model, loader, criterion, device):
    model.eval()
    total = 0.0
    with torch.no_grad():
        for xb, yb in loader:
            xb = xb.to(device)
            yb = yb.to(device)
            pred = model(xb)
            loss = criterion(pred, yb)
            total += loss.item() * xb.size(0)
    return total / len(loader.dataset)


# -------------------- Main --------------------
if __name__ == "__main__":
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")

    # 1) Load & clean
    raw = pd.read_csv(CSV_PATH)
    df = clean_dataframe(raw)

    # 2) Split
    df_train, df_val, df_test = train_val_test_split(df)

    # 3) Scale (train-only for tuning)
    scaler = StandardScaler()
    train_scaled = scaler.fit_transform(df_train[[TARGET_COL]])
    val_scaled   = scaler.transform(df_val[[TARGET_COL]])

    # -------- Optuna objective --------
    def objective(trial: optuna.Trial):
        lookback   = trial.suggest_int("lookback", 1, 30)
        num_layers = trial.suggest_int("num_layers", 1, 3)
        hidden_sz  = trial.suggest_int("hidden_size", 16, 128, log=True)
        lr         = trial.suggest_float("lr", 1e-4, 1e-2, log=True)
        batch_size = trial.suggest_categorical("batch_size", [16, 32, 64])
        epochs     = 100

        Xtr, ytr = create_sequences(train_scaled, lookback)
        # To create validation sequences, prepend last lookback rows of train to val
        Xval_in = np.vstack([train_scaled[-lookback:], val_scaled])
        yval_in = np.concatenate([train_scaled[-lookback:,0], val_scaled[:,0]])
        Xva, yva = create_sequences(Xval_in, lookback)

        train_ds = SeqDataset(Xtr, ytr)
        val_ds   = SeqDataset(Xva, yva)
        train_ld = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
        val_ld   = DataLoader(val_ds, batch_size=batch_size, shuffle=False)

        # Use GRURegressor
        model = GRURegressor(input_size=1, hidden_size=hidden_sz, num_layers=num_layers).to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=lr)
        criterion = nn.MSELoss()

        best_val = float('inf')
        patience, wait = 5, 0

        for epoch in range(epochs):
            train_epoch(model, train_ld, criterion, optimizer, device)
            val_loss = eval_epoch(model, val_ld, criterion, device)
            if val_loss < best_val - 1e-6:
                best_val = val_loss
                wait = 0
            else:
                wait += 1
                if wait >= patience:
                    break

        return math.sqrt(best_val)  # RMSE

    study = optuna.create_study(direction="minimize")
    study.optimize(objective, n_trials=500, n_jobs=-1)

    print("Best hyperparameters:", study.best_params)
    print("Best validation RMSE:", study.best_value)

    # 4) Final train on train+val with best params
    best = study.best_params
    lookback   = best["lookback"]
    num_layers = best["num_layers"]
    hidden_sz  = best["hidden_size"]
    lr         = best["lr"]
    batch_size = best["batch_size"]

    full_scaler = StandardScaler()
    trainval_scaled = full_scaler.fit_transform(pd.concat([df_train, df_val])[ [TARGET_COL] ])

    Xtrv, ytrv = create_sequences(trainval_scaled, lookback)
    trainval_ds = SeqDataset(Xtrv, ytrv)
    trainval_ld = DataLoader(trainval_ds, batch_size=batch_size, shuffle=True)

    # Use GRURegressor
    model_final = GRURegressor(input_size=1, hidden_size=hidden_sz, num_layers=num_layers).to(device)
    optimizer   = torch.optim.Adam(model_final.parameters(), lr=lr)
    criterion   = nn.MSELoss()

    EPOCHS_FINAL = 50
    for _ in range(EPOCHS_FINAL):
        train_epoch(model_final, trainval_ld, criterion, optimizer, device)

    # 5) Rolling forecast on test set (recursive, on scaled values)
    history = trainval_scaled.tolist()  # list of [scaled_price]
    preds_scaled = []
    with torch.no_grad():
        for _ in range(len(df_test)):
            x_in = np.array(history[-lookback:]).reshape(1, lookback, 1).astype(np.float32)
            x_tensor = torch.from_numpy(x_in).to(device)
            yhat = model_final(x_tensor).cpu().numpy().ravel()[0]
            preds_scaled.append(yhat)
            history.append([yhat])  # append predicted (scaled) value for next step

    preds = full_scaler.inverse_transform(np.array(preds_scaled).reshape(-1,1)).ravel()

    # 6) Metrics & Plot
    y_test = df_test[TARGET_COL].values
    metrics = evaluate_metrics(y_test, preds)
    print("Rolling Forecast Test Metrics:", json.dumps(metrics, indent=2))

    plt.figure(figsize=(12,5))
    plt.plot(df_test[DATE_COL], y_test, label='Actual')
    plt.plot(df_test[DATE_COL], preds, label='Predicted', linestyle='--')
    plt.title('PyTorch GRU Rolling Forecast — Actual vs Predicted (2024)')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.tight_layout()
    plt.show()

    # Save best params for reproducibility
    # with open('best_gru_params.json', 'w') as f:
    #     json.dump({"best_params": study.best_params, "best_val_rmse": study.best_value}, f, indent=2)
    # print("Saved best params to best_gru_params.json")
# Out:
# [I 2025-08-15 15:04:09,890] A new study created in memory with name: no-name-442a8461-2dce-43ef-9b4c-e1b0fe9eaad0
# Using device: cuda
# [I 2025-08-15 15:04:12,987] Trial 3 finished with value: 0.1396130470301024 and parameters: {'lookback': 6, 'num_layers': 1, 'hidden_size': 114, 'lr': 0.00032221558801069465, 'batch_size': 32}. Best is trial 3 with value: 0.1396130470301024.
# [I 2025-08-15 15:04:13,916] Trial 4 finished with value: 0.3165118574666078 and parameters: {'lookback': 11, 'num_layers': 3, 'hidden_size': 31, 'lr': 0.00014852600029806638, 'batch_size': 64}. Best is trial 3 with value: 0.1396130470301024.
# [I 2025-08-15 15:04:16,316] Trial 11 finished with value: 0.08426662165709899 and parameters: {'lookback': 23, 'num_layers': 3, 'hidden_size': 19, 'lr': 0.005790537584041278, 'batch_size': 32}. Best is trial 11 with value: 0.08426662165709899.
# [I 2025-08-15 15:04:17,128] Trial 1 finished with value: 0.09734453593738823 and parameters: {'lookback': 2, 'num_layers': 1, 'hidden_size': 30, 'lr': 0.00043223386527094774, 'batch_size': 32}. Best is trial 11 with value: 0.08426662165709899.
# [I 2025-08-15 15:04:18,744] Trial 7 finished with value: 0.08129120388044071 and parameters: {'lookback': 20, 'num_layers': 3, 'hidden_size': 74, 'lr': 0.009012264964678881, 'batch_size': 64}. Best is trial 7 with value: 0.08129120388044071.
# [I 2025-08-15 15:04:19,464] Trial 0 finished with value: 0.07989397295038288 and parameters: {'lookback': 14, 'num_layers': 3, 'hidden_size': 92, 'lr': 0.0043917523288210395, 'batch_size': 16}. Best is trial 0 with value: 0.07989397295038288.
# [I 2025-08-15 15:04:20,003] Trial 12 finished with value: 0.08536652416688698 and parameters: {'lookback': 23, 'num_layers': 1, 'hidden_size': 45, 'lr': 0.0038143265235987397, 'batch_size': 32}. Best is trial 0 with value: 0.07989397295038288.
# [I 2025-08-15 15:04:21,316] Trial 10 finished with value: 0.12455478611909138 and parameters: {'lookback': 10, 'num_layers': 1, 'hidden_size': 19, 'lr': 0.00020783460803952563, 'batch_size': 32}. Best is trial 0 with value: 0.07989397295038288.
# [I 2025-08-15 15:04:23,828] Trial 2 finished with value: 0.08187363795988807 and parameters: {'lookback': 16, 'num_layers': 2, 'hidden_size': 40, 'lr': 0.0010319457315279314, 'batch_size': 16}. Best is trial 0 with value: 0.07989397295038288.
# [I 2025-08-15 15:04:23,903] Trial 5 finished with value: 0.08427937247026575 and parameters: {'lookback': 17, 'num_layers': 3, 'hidden_size':
 'batch_size': 16}. Best is trial 427 with value: 0.0792454190765247.
# [I 2025-08-15 15:12:50,383] Trial 492 finished with value: 0.07980013428616245 and parameters: {'lookback': 13, 'num_layers': 2, 'hidden_size': 31, 'lr': 0.004006023645942121, 'batch_size': 16}. Best is trial 427 with value: 0.0792454190765247.
# [I 2025-08-15 15:12:51,886] Trial 497 finished with value: 0.0813283840861603 and parameters: {'lookback': 13, 'num_layers': 2, 'hidden_size': 29, 'lr': 0.003607746604642013, 'batch_size': 16}. Best is trial 427 with value: 0.0792454190765247.
# [I 2025-08-15 15:12:52,659] Trial 484 finished with value: 0.07971503097785955 and parameters: {'lookback': 13, 'num_layers': 2, 'hidden_size': 32, 'lr': 0.0047627217817229955, 'batch_size': 16}. Best is trial 427 with value: 0.0792454190765247.
# [I 2025-08-15 15:12:54,013] Trial 498 finished with value: 0.07967165956857428 and parameters: {'lookback': 14, 'num_layers': 2, 'hidden_size': 29, 'lr': 0.0037700556346009616, 'batch_size': 16}. Best is trial 427 with value: 0.0792454190765247.
# [I 2025-08-15 15:12:55,250] Trial 467 finished with value: 0.07966600471782126 and parameters: {'lookback': 15, 'num_layers': 2, 'hidden_size': 29, 'lr': 0.003811223942425305, 'batch_size': 16}. Best is trial 427 with value: 0.0792454190765247.
# [I 2025-08-15 15:12:55,510] Trial 485 finished with value: 0.07948758368461707 and parameters: {'lookback': 13, 'num_layers': 2, 'hidden_size': 30, 'lr': 0.004735444449213872, 'batch_size': 16}. Best is trial 427 with value: 0.0792454190765247.
# [I 2025-08-15 15:12:55,568] Trial 499 finished with value: 0.07992636621659005 and parameters: {'lookback': 14, 'num_layers': 2, 'hidden_size': 29, 'lr': 0.0035768059489461436, 'batch_size': 16}. Best is trial 427 with value: 0.0792454190765247.
# [I 2025-08-15 15:12:56,980] Trial 435 finished with value: 0.07972790162342273 and parameters: {'lookback': 14, 'num_layers': 2, 'hidden_size': 27, 'lr': 0.003764654937904923, 'batch_size': 16}. Best is trial 427 with value: 0.0792454190765247.
# [I 2025-08-15 15:12:57,694] Trial 457 finished with value: 0.0815044578925907 and parameters: {'lookback': 14, 'num_layers': 2, 'hidden_size': 27, 'lr': 0.00415027257287948, 'batch_size': 16}. Best is trial 427 with value: 0.0792454190765247.
# [I 2025-08-15 15:12:57,939] Trial 213 finished with value: 0.07991585227601952 and parameters: {'lookback': 24, 'num_layers': 2, 'hidden_size': 35, 'lr': 0.008181131701761305, 'batch_size': 16}. Best is trial 427 with value: 0.0792454190765247.
# [I 2025-08-15 15:12:58,937] Trial 462 finished with value: 0.07986292213263373 and parameters: {'lookback': 15, 'num_layers': 2, 'hidden_size': 26, 'lr': 0.003163207267638254, 'batch_size': 16}. Best is trial 427 with value: 0.0792454190765247.
# [I 2025-08-15 15:12:58,944] Trial 357 finished with value: 0.0810377539610689 and parameters: {'lookback': 9, 'num_layers': 2, 'hidden_size': 41, 'lr': 0.009763710776867076, 'batch_size': 16}. Best is trial 427 with value: 0.0792454190765247.
# Best hyperparameters: {'lookback': 16, 'num_layers': 2, 'hidden_size': 27, 'lr': 0.004842371590853855, 'batch_size': 16}
# Best validation RMSE: 0.0792454190765247
# Rolling Forecast Test Metrics: {
#   "MSE": 633.6482745042485,
#   "RMSE": 25.172371253107016,
#   "MAE": 24.25816954361765,
#   "MAPE%": 37.931991757032684,
#   "R2": -17.087044366043177
# }

# %%
"""
Modified: Carbon Price Forecasting with PyTorch GRU
- Multi-step Rolling Forecast (5 steps) on Test Set.
- The model predicts 5 days at a time. The ground truth is used to advance the window.
"""

import os
import math
import json
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import optuna

# -------------------- Config --------------------
RANDOM_STATE = 42
CSV_PATH = "Carbon_Emissions_Futures_2021_Onwards.csv"
DATE_COL = "Date"
TARGET_COL = "Price"
FORECAST_STEPS = 1 # Number of steps to forecast ahead

# Reproducibility
random.seed(RANDOM_STATE)
np.random.seed(RANDOM_STATE)
torch.manual_seed(RANDOM_STATE)

# -------------------- Data utils --------------------
def _parse_volume(v):
    if pd.isna(v):
        return np.nan
    if isinstance(v, (int, float)):
        return float(v)
    s = str(v).strip().replace(",", "")
    if s.endswith(("K","k")):
        return float(s[:-1]) * 1_000
    if s.endswith(("M","m")):
        return float(s[:-1]) * 1_000_000
    return float(s)

def clean_dataframe(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    df.rename(columns={"Vol.": "Volume", "Change %": "ChangePct"}, inplace=True)
    df[DATE_COL] = pd.to_datetime(df[DATE_COL], dayfirst=True, errors='coerce')
    for col in ["Price", "Open", "High", "Low"]:
        df[col] = pd.to_numeric(df[col], errors='coerce')
    if "Volume" in df:
        df["Volume"] = df["Volume"].apply(_parse_volume)
    if "ChangePct" in df:
        df["ChangePct"] = pd.to_numeric(df["ChangePct"].astype(str).str.replace('%',''), errors='coerce') / 100.0
    df = df.dropna(subset=[DATE_COL]).sort_values(DATE_COL).reset_index(drop=True)
    return df

def train_val_test_split(df: pd.DataFrame):
    train_mask = (df[DATE_COL] >= '2021-01-01') & (df[DATE_COL] <= '2023-12-31')
    test_mask  = (df[DATE_COL] >= '2024-01-01') & (df[DATE_COL] <= '2024-12-31')
    df_train_full = df.loc[train_mask].copy()
    df_test = df.loc[test_mask].copy()
    split_idx = int(len(df_train_full) * 0.9)
    return df_train_full.iloc[:split_idx], df_train_full.iloc[split_idx:], df_test

def create_sequences(series_2d: np.ndarray, lookback: int):
    X, y = [], []
    for i in range(lookback, len(series_2d)):
        X.append(series_2d[i-lookback:i])
        y.append(series_2d[i, 0])
    return np.asarray(X, dtype=np.float32), np.asarray(y, dtype=np.float32)

class SeqDataset(Dataset):
    def __init__(self, X: np.ndarray, y: np.ndarray):
        self.X = X
        self.y = y
    def __len__(self):
        return len(self.X)
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# -------------------- Model --------------------
class GRURegressor(nn.Module):
    def __init__(self, input_size: int, hidden_size: int, num_layers: int):
        super().__init__()
        self.gru = nn.GRU(input_size=input_size, hidden_size=hidden_size, num_layers=num_layers, batch_first=True)
        self.head = nn.Linear(hidden_size, 1)
    def forward(self, x):
        out, _ = self.gru(x)
        last = out[:, -1, :]
        return self.head(last).squeeze(-1)

# -------------------- Metrics --------------------
def evaluate_metrics(y_true, y_pred):
    mse = mean_squared_error(y_true, y_pred)
    rmse = math.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    mape = np.mean(np.abs((y_true - y_pred) / np.clip(np.abs(y_true), 1e-8, None))) * 100
    r2 = r2_score(y_true, y_pred)
    return {"MSE": mse, "RMSE": rmse, "MAE": mae, "MAPE%": mape, "R2": r2}

# -------------------- Training loop --------------------
def train_epoch(model, loader, criterion, optimizer, device):
    model.train()
    total = 0.0
    for xb, yb in loader:
        xb = xb.to(device)
        yb = yb.to(device)
        optimizer.zero_grad()
        pred = model(xb)
        loss = criterion(pred, yb)
        loss.backward()
        optimizer.step()
        total += loss.item() * xb.size(0)
    return total / len(loader.dataset)

def eval_epoch(model, loader, criterion, device):
    model.eval()
    total = 0.0
    with torch.no_grad():
        for xb, yb in loader:
            xb = xb.to(device)
            yb = yb.to(device)
            pred = model(xb)
            loss = criterion(pred, yb)
            total += loss.item() * xb.size(0)
    return total / len(loader.dataset)

# -------------------- Main --------------------
if __name__ == "__main__":
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")

    raw = pd.read_csv(CSV_PATH)
    df = clean_dataframe(raw)
    df_train, df_val, df_test = train_val_test_split(df)
    
    scaler = StandardScaler()
    train_scaled = scaler.fit_transform(df_train[[TARGET_COL]])
    val_scaled   = scaler.transform(df_val[[TARGET_COL]])

    def objective(trial: optuna.Trial):
        lookback   = trial.suggest_int("lookback", 2, 30)
        num_layers = trial.suggest_int("num_layers", 1, 3)
        hidden_sz  = trial.suggest_int("hidden_size", 16, 128, log=True)
        lr         = trial.suggest_float("lr", 1e-4, 1e-2, log=True)
        batch_size = trial.suggest_categorical("batch_size", [16, 32, 64])
        epochs     = 100

        Xtr, ytr = create_sequences(train_scaled, lookback)
        Xval_in = np.vstack([train_scaled[-lookback:], val_scaled])
        yval_in = np.concatenate([train_scaled[-lookback:,0], val_scaled[:,0]])
        Xva, yva = create_sequences(Xval_in, lookback)

        train_ds = SeqDataset(Xtr, ytr)
        val_ds   = SeqDataset(Xva, yva)
        train_ld = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
        val_ld   = DataLoader(val_ds, batch_size=batch_size, shuffle=False)

        model = GRURegressor(input_size=1, hidden_size=hidden_sz, num_layers=num_layers).to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=lr)
        criterion = nn.MSELoss()

        best_val = float('inf')
        patience, wait = 5, 0
        for epoch in range(epochs):
            train_epoch(model, train_ld, criterion, optimizer, device)
            val_loss = eval_epoch(model, val_ld, criterion, device)
            if val_loss < best_val - 1e-6:
                best_val = val_loss
                wait = 0
            else:
                wait += 1
                if wait >= patience:
                    break
        return math.sqrt(best_val)

    study = optuna.create_study(direction="minimize")
    study.optimize(objective, n_trials=200)

    print("Best hyperparameters:", study.best_params)
    print("Best validation RMSE:", study.best_value)

    best = study.best_params
    lookback   = best["lookback"]
    num_layers = best["num_layers"]
    hidden_sz  = best["hidden_size"]
    lr         = best["lr"]
    batch_size = best["batch_size"]

    full_scaler = StandardScaler()
    trainval_scaled = full_scaler.fit_transform(pd.concat([df_train, df_val])[ [TARGET_COL] ])
    Xtrv, ytrv = create_sequences(trainval_scaled, lookback)
    trainval_ds = SeqDataset(Xtrv, ytrv)
    trainval_ld = DataLoader(trainval_ds, batch_size=batch_size, shuffle=True)
    model_final = GRURegressor(input_size=1, hidden_size=hidden_sz, num_layers=num_layers).to(device)
    optimizer   = torch.optim.Adam(model_final.parameters(), lr=lr)
    criterion   = nn.MSELoss()

    EPOCHS_FINAL = 50
    for _ in range(EPOCHS_FINAL):
        train_epoch(model_final, trainval_ld, criterion, optimizer, device)

    # -------------------- Multi-step rolling forecast loop (MODIFIED) --------------------
    history = trainval_scaled.tolist()
    preds_scaled = []
    y_test_scaled = full_scaler.transform(df_test[[TARGET_COL]]).tolist()

    with torch.no_grad():
        for i in range(0, len(df_test), FORECAST_STEPS):
            # A) Make multi-step predictions based on current history
            temp_history = history.copy()
            block_preds = []
            for _ in range(FORECAST_STEPS):
                x_in = np.array(temp_history[-lookback:]).reshape(1, lookback, 1).astype(np.float32)
                x_tensor = torch.from_numpy(x_in).to(device)
                yhat = model_final(x_tensor).cpu().numpy().ravel()[0]
                block_preds.append(yhat)
                temp_history.append([yhat]) # Use prediction for the next step within the block
            
            preds_scaled.extend(block_preds)

            # B) Advance the window using ground truth
            for j in range(FORECAST_STEPS):
                if i + j < len(df_test):
                    history.append(y_test_scaled[i + j])
                else:
                    break
    
    preds_scaled = preds_scaled[:len(df_test)]

    preds = full_scaler.inverse_transform(np.array(preds_scaled).reshape(-1,1)).ravel()

    # -------------------- Metrics & Plot --------------------
    y_test = df_test[TARGET_COL].values
    metrics = evaluate_metrics(y_test, preds)
    print("Multi-step Rolling Forecast (1-day blocks) Test Metrics:", json.dumps(metrics, indent=2))

    plt.figure(figsize=(12,5))
    plt.plot(df_test[DATE_COL], y_test, label='Actual')
    plt.plot(df_test[DATE_COL], preds, label='Predicted', linestyle='--')
    plt.title('PyTorch GRU Multi-Step Forecast — Actual vs Predicted (2024)')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.tight_layout()
    plt.savefig('gru_pytorch_multistep_forecast_2024.png', dpi=150)
    print("Saved plot to gru_pytorch_multistep_forecast_2024.png")

    with open('best_gru_params_multistep.json', 'w') as f:
        json.dump({"best_params": study.best_params, "best_val_rmse": study.best_value}, f, indent=2)
    print("Saved best params to best_gru_params_multistep.json")
# Out:
# [I 2025-08-15 18:40:39,206] A new study created in memory with name: no-name-95839bd3-b6d2-4e5e-bf98-325409a3b535
# Using device: cuda
# [I 2025-08-15 18:40:39,744] Trial 0 finished with value: 0.15610338968300183 and parameters: {'lookback': 17, 'num_layers': 2, 'hidden_size': 20, 'lr': 0.000577391065411947, 'batch_size': 64}. Best is trial 0 with value: 0.15610338968300183.
# [I 2025-08-15 18:40:42,733] Trial 1 finished with value: 0.08440770255187645 and parameters: {'lookback': 15, 'num_layers': 3, 'hidden_size':
 'batch_size': 16}. Best is trial 161 with value: 0.0789629505761585.
# [I 2025-08-15 18:57:14,792] Trial 182 finished with value: 0.08130885492912555 and parameters: {'lookback': 9, 'num_layers': 3, 'hidden_size': 50, 'lr': 0.006692770252292425, 'batch_size': 16}. Best is trial 161 with value: 0.0789629505761585.
# [I 2025-08-15 18:57:27,045] Trial 183 finished with value: 0.08119031161606063 and parameters: {'lookback': 2, 'num_layers': 3, 'hidden_size': 76, 'lr': 0.005365241933562567, 'batch_size': 16}. Best is trial 161 with value: 0.0789629505761585.
# [I 2025-08-15 18:57:34,825] Trial 184 finished with value: 0.08184045423510572 and parameters: {'lookback': 23, 'num_layers': 3, 'hidden_size': 52, 'lr': 0.0021917282926553266, 'batch_size': 16}. Best is trial 161 with value: 0.0789629505761585.
# [I 2025-08-15 18:57:43,298] Trial 185 finished with value: 0.08036777698549499 and parameters: {'lookback': 16, 'num_layers': 3, 'hidden_size': 24, 'lr': 0.008308551608140962, 'batch_size': 16}. Best is trial 161 with value: 0.0789629505761585.
# [I 2025-08-15 18:57:48,515] Trial 186 finished with value: 0.08107749705230252 and parameters: {'lookback': 28, 'num_layers': 3, 'hidden_size': 67, 'lr': 0.007787216177362511, 'batch_size': 16}. Best is trial 161 with value: 0.0789629505761585.
# [I 2025-08-15 18:57:54,763] Trial 187 finished with value: 0.0803860561273751 and parameters: {'lookback': 22, 'num_layers': 3, 'hidden_size': 47, 'lr': 0.006127966204966909, 'batch_size': 16}. Best is trial 161 with value: 0.0789629505761585.
# [I 2025-08-15 18:58:03,539] Trial 188 finished with value: 0.08561771324713158 and parameters: {'lookback': 8, 'num_layers': 3, 'hidden_size': 54, 'lr': 0.0027024351503052197, 'batch_size': 16}. Best is trial 161 with value: 0.0789629505761585.
# [I 2025-08-15 18:58:14,265] Trial 189 finished with value: 0.08188563550060662 and parameters: {'lookback': 10, 'num_layers': 3, 'hidden_size': 62, 'lr': 0.009054117375959087, 'batch_size': 16}. Best is trial 161 with value: 0.0789629505761585.
# [I 2025-08-15 18:58:19,562] Trial 190 finished with value: 0.07948031321468169 and parameters: {'lookback': 21, 'num_layers': 3, 'hidden_size': 18, 'lr': 0.007102631824682531, 'batch_size': 64}. Best is trial 161 with value: 0.0789629505761585.
# [I 2025-08-15 18:58:25,905] Trial 191 finished with value: 0.08057822427569827 and parameters: {'lookback': 22, 'num_layers': 3, 'hidden_size': 18, 'lr': 0.007133588582794955, 'batch_size': 64}. Best is trial 161 with value: 0.0789629505761585.
# [I 2025-08-15 18:58:29,417] Trial 192 finished with value: 0.0829710676241724 and parameters: {'lookback': 24, 'num_layers': 3, 'hidden_size': 17, 'lr': 0.006666117288140702, 'batch_size': 64}. Best is trial 161 with value: 0.0789629505761585.
# [I 2025-08-15 18:58:33,891] Trial 193 finished with value: 0.07991106347062778 and parameters: {'lookback': 21, 'num_layers': 3, 'hidden_size': 19, 'lr': 0.008208625758689289, 'batch_size': 64}. Best is trial 161 with value: 0.0789629505761585.
# [I 2025-08-15 18:58:36,403] Trial 194 finished with value: 0.08751608825990302 and parameters: {'lookback': 21, 'num_layers': 3, 'hidden_size': 18, 'lr': 0.009982682285817111, 'batch_size': 64}. Best is trial 161 with value: 0.0789629505761585.
# [I 2025-08-15 18:58:41,403] Trial 195 finished with value: 0.08307946235654595 and parameters: {'lookback': 16, 'num_layers': 3, 'hidden_size': 94, 'lr': 0.0012027227488232168, 'batch_size': 64}. Best is trial 161 with value: 0.0789629505761585.
# [I 2025-08-15 18:58:48,332] Trial 196 finished with value: 0.08028871627767498 and parameters: {'lookback': 15, 'num_layers': 3, 'hidden_size': 51, 'lr': 0.007575688073742487, 'batch_size': 16}. Best is trial 161 with value: 0.0789629505761585.
# [I 2025-08-15 18:58:55,128] Trial 197 finished with value: 0.08053380474037425 and parameters: {'lookback': 17, 'num_layers': 3, 'hidden_size': 84, 'lr': 0.005784039441611203, 'batch_size': 16}. Best is trial 161 with value: 0.0789629505761585.
# [I 2025-08-15 18:58:59,828] Trial 198 finished with value: 0.07972749330233694 and parameters: {'lookback': 23, 'num_layers': 3, 'hidden_size': 57, 'lr': 0.008965249751148189, 'batch_size': 32}. Best is trial 161 with value: 0.0789629505761585.
# [I 2025-08-15 18:59:05,620] Trial 199 finished with value: 0.08057971302038741 and parameters: {'lookback': 11, 'num_layers': 3, 'hidden_size': 70, 'lr': 0.006974227061884048, 'batch_size': 16}. Best is trial 161 with value: 0.0789629505761585.
# Best hyperparameters: {'lookback': 17, 'num_layers': 3, 'hidden_size': 60, 'lr': 0.008425182818495414, 'batch_size': 16}
# Best validation RMSE: 0.0789629505761585
# Multi-step Rolling Forecast (1-day blocks) Test Metrics: {
#   "MSE": 3.064895293400411,
#   "RMSE": 1.7506842357776604,
#   "MAE": 1.3249796044199094,
#   "MAPE%": 2.0075972778840323,
#   "R2": 0.9125147193174619
# }
# Saved plot to gru_pytorch_multistep_forecast_2024.png
# Saved best params to best_gru_params_multistep.json
