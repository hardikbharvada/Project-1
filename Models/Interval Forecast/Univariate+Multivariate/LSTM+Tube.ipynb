# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import itertools
import logging

torch.manual_seed(42)
np.random.seed(42)

# --- 1. Configuration ---
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

CONFIG = {
    "file_path": r"C:\Users\DAIICT I\Desktop\Msc DS Sujal 202418017\Interval_Forecast_Normal\df_without_exo.xlsx",
    "target_col": "Carbon_Price_USD",
    "original_features": ['Open', 'High', 'Low', 'Carbon_Price_USD', 'Vol.', 'Change %'],
    
    # --- Splitting Logic ---
    "test_split_date": '2024-04-01',
    "val_ratio_of_train_data": 0.1,
    
    "target_coverage": 95.0,
    "device": torch.device("cuda" if torch.cuda.is_available() else "cpu"),
    
    "param_grid": {
        'seq_len': [5, 10, 15, 20, 25, 30],
        'hidden_dim': [32, 48, 64, 96],
        'num_layers': [1, 2],
        'learning_rate': [0.005, 0.01, 0.001],
        'epochs': [100],
        'q': [0.95, 0.97],
        'r': [0.4, 0.5, 0.6],
        'delta': [0.0, 0.01, 0.1]
    }
}

# --- 2. Model Definition & Loss Function ---

class LSTMTube(nn.Module):
    """LSTM model designed to output two values for the prediction interval."""
    def __init__(self, input_dim, hidden_dim=64, num_layers=1):
        super().__init__()
        # CHANGED: Use nn.LSTM instead of nn.RNN
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True)
        # The final layer still outputs 2 values
        self.fc = nn.Linear(hidden_dim, 2)

    def forward(self, x):
        out, _ = self.lstm(x)
        return self.fc(out[:, -1, :])

def confidence_loss(y_pred, y_true, q, r, delta):
    # This loss function remains the same
    y_true = y_true.squeeze(-1)
    f2 = y_pred[:, 0]
    f1 = y_pred[:, 1]
    crossover_penalty = torch.mean(torch.relu(f1 - f2))
    c1 = (1 - q) * (f2 - y_true)
    c2 = (1 - q) * (y_true - f1)
    c3 = q * (f1 - y_true)
    c4 = q * (y_true - f2)
    loss_part1 = torch.where(y_true > r * (f1 + f2), c1, c2)
    loss_part2 = torch.where(f1 > y_true, c3, c4)
    is_inside = torch.logical_and(y_true <= f2, y_true >= f1)
    width_penalty = delta * torch.abs(f1 - f2)
    final_loss = torch.where(is_inside, loss_part1, loss_part2) + width_penalty
    return torch.mean(final_loss) + crossover_penalty

def crps_score(y_true, pred_lower, pred_upper):
    """
    Calculates the CRPS for a quantile-based forecast.
    This is an approximation based on the two quantiles.
    
    Args:
        y_true (np.array): The true values.
        pred_lower (np.array): The lower quantile predictions (e.g., 2.5th).
        pred_upper (np.array): The upper quantile predictions (e.g., 97.5th).

    Returns:
        float: The average CRPS score.
    """
    alpha = 0.05  # For a 95% interval (1 - alpha)
    
    # This is an approximation of CRPS for quantile forecasts.
    # It penalizes being outside the interval and also accounts for wide intervals.
    crps = np.mean(
        (y_true - pred_lower) * ((y_true > pred_lower) - (1 - alpha / 2)) +
        (pred_upper - y_true) * ((y_true < pred_upper) - (alpha / 2))
    )
    return crps

# --- 3. Pipeline Functions ---

def load_and_clean_data(file_path):
    # This function remains the same
    logging.info(f"Loading data from {file_path}...")
    df = pd.read_excel(file_path) 
    df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)
    df.sort_values('Date', inplace=True)
    if pd.api.types.is_object_dtype(df['Vol.']):
        def convert_volume(vol):
            try:
                if isinstance(vol, str):
                    vol = vol.replace('K', '*1e3').replace('M', '*1e6')
                    return eval(vol)
                return np.nan
            except: return np.nan
        df['Vol.'] = df['Vol.'].apply(convert_volume)
    df['Vol.'] = pd.to_numeric(df['Vol.'], errors='coerce')
    df['Change %'] = pd.to_numeric(df['Change %'], errors='coerce')
    df.set_index('Date', inplace=True)
    return df

def engineer_features(df, original_features, target_col):
    # This function remains the same
    logging.info("Engineering lagged features...")
    for feature in original_features:
        df[f'{feature}_lag1'] = df[feature].shift(1)
    feature_cols = [f'{col}_lag1' for col in original_features]
    df.dropna(inplace=True)
    if df.empty:
        raise ValueError("DataFrame is empty after feature engineering.")
    X = df[feature_cols]
    y = df[[target_col]]
    return X, y

def split_and_scale_data(X, y, test_split_date, val_ratio):
    # This function remains the same
    logging.info(f"Splitting test data at date: {test_split_date}")
    test_split_date = pd.to_datetime(test_split_date)
    train_val_mask = X.index < test_split_date
    X_train_val, X_test = X[train_val_mask], X[~train_val_mask]
    y_train_val, y_test = y[train_val_mask], y[~train_val_mask]
    val_split_index = int(len(X_train_val) * (1 - val_ratio))
    X_train, X_val = X_train_val[:val_split_index], X_train_val[val_split_index:]
    y_train, y_val = y_train_val[:val_split_index], y_train_val[val_split_index:]
    logging.info(f"Train size: {len(X_train)}, Validation size: {len(X_val)}, Test size: {len(X_test)}")
    if len(X_train) == 0 or len(X_val) == 0 or len(X_test) == 0:
         raise ValueError("One of the data splits is empty.")
    scaler_X = MinMaxScaler()
    scaler_y = MinMaxScaler()
    X_train_scaled = scaler_X.fit_transform(X_train)
    y_train_scaled = scaler_y.fit_transform(y_train)
    X_val_scaled = scaler_X.transform(X_val)
    y_val_scaled = scaler_y.transform(y_val)
    X_test_scaled = scaler_X.transform(X_test)
    y_test_scaled = scaler_y.transform(y_test)
    return (X_train_scaled, y_train_scaled, X_val_scaled, y_val_scaled, 
            X_test_scaled, y_test_scaled, scaler_y)

def create_sequences(X, y, seq_len):
    # This function remains the same
    X_seq, y_seq = [], []
    for i in range(seq_len, len(X)):
        X_seq.append(X[i - seq_len:i])
        y_seq.append(y[i])
    return np.array(X_seq), np.array(y_seq)

def train_tube_model(X_train, y_train, params):
    """Trains a single LSTM Tube model."""
    # CHANGED: Instantiate LSTMTube instead of RNNTube
    model = LSTMTube(
        X_train.shape[2], 
        params['hidden_dim'], 
        params['num_layers']
    ).to(CONFIG['device'])
    
    optimizer = torch.optim.Adam(model.parameters(), lr=params['learning_rate'])
    X_train_t = torch.tensor(X_train, dtype=torch.float32).to(CONFIG['device'])
    y_train_t = torch.tensor(y_train, dtype=torch.float32).to(CONFIG['device'])
    q, r, delta = params['q'], params['r'], params['delta']

    for _ in range(params['epochs']):
        model.train()
        optimizer.zero_grad()
        y_pred = model(X_train_t)
        loss = confidence_loss(y_pred, y_train_t, q, r, delta)
        loss.backward()
        optimizer.step()
    return model

def find_best_hyperparameters(train_data, val_data, param_grid, scaler_y):
    # This function is modified to use CRPS for model selection
    X_train_scaled, y_train_scaled = train_data
    X_val_scaled, y_val_scaled = val_data
    valid_models = []
    param_combinations = list(itertools.product(*param_grid.values()))
    logging.info(f"Starting hyperparameter search over {len(param_combinations)} combinations...")

    for values in param_combinations:
        params = dict(zip(param_grid.keys(), values))
        X_train_seq, y_train_seq = create_sequences(X_train_scaled, y_train_scaled, params['seq_len'])
        X_val_seq, y_val_seq = create_sequences(X_val_scaled, y_val_scaled, params['seq_len'])
        if len(X_val_seq) == 0: continue
        model = train_tube_model(X_train_seq, y_train_seq, params)
        X_val_t = torch.tensor(X_val_seq, dtype=torch.float32).to(CONFIG['device'])
        with torch.no_grad():
            predictions = model(X_val_t).cpu().numpy()
        pred_upper_s = predictions[:, 0:1]
        pred_lower_s = predictions[:, 1:2]
        pred_lower = scaler_y.inverse_transform(pred_lower_s).flatten()
        pred_upper = scaler_y.inverse_transform(pred_upper_s).flatten()
        y_val_true = scaler_y.inverse_transform(y_val_seq).flatten()
        pred_lower, pred_upper = np.minimum(pred_lower, pred_upper), np.maximum(pred_lower, pred_upper)
        picp = np.mean((y_val_true >= pred_lower) & (y_val_true <= pred_upper)) * 100
        mpiw = np.mean(pred_upper - pred_lower)
        crps = crps_score(y_val_true, pred_lower, pred_upper)
        if picp >= CONFIG['target_coverage']:
            logging.info(f"✓ Valid model found: PICP={picp:.2f}%, MPIW={mpiw:.4f}, CRPS={crps:.4f} with params {params}")
            valid_models.append({'mpiw': mpiw, 'crps': crps, 'params': params})
        else:
            logging.info(f"✗ Model rejected: PICP={picp:.2f}% with params {params}")
    if not valid_models:
        raise ValueError("No valid hyperparameters found that meet the PICP threshold.")
    best_model_info = min(valid_models, key=lambda x: x['crps'])
    return best_model_info['params']

def evaluate_on_test_set(best_params, train_val_data, test_data, scaler_y):
    # This function is modified to include CRPS in the final results
    X_train_val_scaled, y_train_val_scaled = train_val_data
    X_test_scaled, y_test_scaled = test_data
    logging.info("Training final model on combined train+validation data...")
    X_train_val_seq, y_train_val_seq = create_sequences(X_train_val_scaled, y_train_val_scaled, best_params['seq_len'])
    X_test_seq, y_test_seq = create_sequences(X_test_scaled, y_test_scaled, best_params['seq_len'])
    model = train_tube_model(X_train_val_seq, y_train_val_seq, best_params)
    logging.info("Evaluating final model on the test set...")
    X_test_t = torch.tensor(X_test_seq, dtype=torch.float32).to(CONFIG['device'])
    with torch.no_grad():
        predictions = model(X_test_t).cpu().numpy()
    pred_upper_s = predictions[:, 0:1]
    pred_lower_s = predictions[:, 1:2]
    pred_lower = scaler_y.inverse_transform(pred_lower_s).flatten()
    pred_upper = scaler_y.inverse_transform(pred_upper_s).flatten()
    y_test_true = scaler_y.inverse_transform(y_test_seq).flatten()
    pred_lower, pred_upper = np.minimum(pred_lower, pred_upper), np.maximum(pred_lower, pred_upper)
    final_picp = np.mean((y_test_true >= pred_lower) & (y_test_true <= pred_upper)) * 100
    final_mpiw = np.mean(pred_upper - pred_lower)
    final_crps = crps_score(y_test_true, pred_lower, pred_upper)
    results = {"picp": final_picp, "mpiw": final_mpiw, "crps": final_crps}
    plot_data = {"pred_lower": pred_lower, "pred_upper": pred_upper, "y_true": y_test_true}
    return results, plot_data

def plot_results(plot_data, test_dates):
    # This function remains the same
    logging.info("Generating final plot...")
    y_true = plot_data['y_true']
    dates_for_plot = test_dates[-len(y_true):]
    plt.figure(figsize=(15, 7))
    plt.plot(dates_for_plot, y_true, label='Actual Price', color='black', linewidth=1.5)
    plt.fill_between(dates_for_plot, plot_data['pred_lower'], plot_data['pred_upper'], 
                     color='dodgerblue', alpha=0.3, label=f'Prediction Interval')
    plt.title('Final Model Evaluation on Test Set (LSTM+Tube)')
    plt.xlabel('Date')
    plt.ylabel(CONFIG['target_col'])
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.show()

# --- 4. Main Execution ---
def main():
    # This function remains the same
    df = load_and_clean_data(CONFIG['file_path'])
    X, y = engineer_features(df, CONFIG['original_features'], CONFIG['target_col'])
    (X_train_s, y_train_s, X_val_s, y_val_s, 
     X_test_s, y_test_s, scaler_y) = split_and_scale_data(
         X, y, 
         test_split_date=CONFIG['test_split_date'], 
         val_ratio=CONFIG['val_ratio_of_train_data']
    )
    best_params = find_best_hyperparameters(
        train_data=(X_train_s, y_train_s),
        val_data=(X_val_s, y_val_s),
        param_grid=CONFIG['param_grid'],
        scaler_y=scaler_y
    )
    X_train_val_s = np.concatenate((X_train_s, X_val_s), axis=0)
    y_train_val_s = np.concatenate((y_train_s, y_val_s), axis=0)
    final_results, plot_data = evaluate_on_test_set(
        best_params=best_params,
        train_val_data=(X_train_val_s, y_train_val_s),
        test_data=(X_test_s, y_test_s),
        scaler_y=scaler_y
    )
    print("\n" + "="*40)
    logging.info("Final Model Performance on Test Set")
    print("="*40)
    print(f"Best Hyperparameters: {best_params}")
    print(f"Prediction Interval Coverage (PICP): {final_results['picp']:.2f}%")
    print(f"Mean Prediction Interval Width (MPIW): {final_results['mpiw']:.4f}")
    print(f"Continuous Ranked Probability Score (CRPS): {final_results['crps']:.4f}")
    print("="*40 + "\n")
    test_dates_index = X[X.index >= pd.to_datetime(CONFIG['test_split_date'])].index
    plot_results(plot_data, test_dates=test_dates_index)

if __name__ == "__main__":
    main()
# Out:
# 2025-08-24 03:45:15,432 - INFO - Loading data from C:\Users\DAIICT I\Desktop\Msc DS Sujal 202418017\Interval_Forecast_Normal\df_without_exo.xlsx...
# 2025-08-24 03:45:15,559 - INFO - Engineering lagged features...
# 2025-08-24 03:45:15,562 - INFO - Splitting test data at date: 2024-04-01
# 2025-08-24 03:45:15,564 - INFO - Train size: 750, Validation size: 84, Test size: 89
# 2025-08-24 03:45:15,568 - INFO - Starting hyperparameter search over 2592 combinations...
# 2025-08-24 03:45:17,320 - INFO - ✗ Model rejected: PICP=93.67% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 03:45:17,823 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=24.3655, CRPS=16.6073 with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.01}
# 2025-08-24 03:45:18,289 - INFO - ✗ Model rejected: PICP=82.28% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 03:45:18,780 - INFO - ✗ Model rejected: PICP=92.41% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 03:45:19,258 - INFO - ✓ Valid model found: PICP=98.73%, MPIW=27.8051, CRPS=20.0098 with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.01}
# 2025-08-24 03:45:19,710 - INFO - ✗ Model rejected: PICP=81.01% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 03:45:20,181 - INFO - ✗ Model rejected: PICP=94.94% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 03:45:20,662 - INFO - ✗ Model rejected: PICP=93.67% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.01}
# 2025-08-24 03:45:21,107 - INFO - ✗ Model rejected: PICP=81.01% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 03:45:21,530 - INFO - ✗ Model rejected: PICP=93.67% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 03:45:22,001 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=26.0466, CRPS=16.2583 with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.01}
# 2025-08-24 03:45:22,501 - INFO - ✗ Model rejected: PICP=77.22% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 03:45:22,952 - INFO - ✗ Model rejected: PICP=94.94% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 03:45:23,423 - INFO - ✗ Model rejected: PICP=91.14% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.01}
# 2025-08-24 03:45:23,908 - INFO - ✗ Model rejected: PICP=83.54% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 03:45:24,364 - INFO - ✗ Model rejected: PICP=92.41% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 03:45:24,830 - INFO - ✗ Model rejected: PICP=93.67% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.01}
# 2025-08-24 03:45:25,389 - INFO - ✗ Model rejected: PICP=78.48% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 03:45:25,847 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=186.5801, CRPS=172.7875 with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 03:45:26,276 - INFO - ✓ Valid model found: PICP=97.47%, MPIW=17.0125, CRPS=7.8632 with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.01}
# 2025-08-24 03:45:26,778 - INFO - ✗ Model rejected: PICP=81.01% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 03:45:27,278 - INFO - ✓ Valid model found: PICP=98.73%, MPIW=116.7105, CRPS=107.1687 with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 03:45:27,710 - INFO - ✓ Valid model found: PICP=96.20%, MPIW=20.7757, CRPS=14.2767 with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.01}
# 2025-08-24 03:45:28,189 - INFO - ✗ Model rejected: PICP=75.95% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 03:45:28,658 - INFO - ✗ Model rejected: PICP=92.41% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 03:45:29,136 - INFO - ✗ Model rejected: PICP=93.67% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.01}
# 2025-08-24 03:45:29,633 - INFO - ✗ Model rejected: PICP=70.89% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 03:45:30,101 - INFO - ✗ Model rejected: PICP=88.61% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 03:45:30,561 - INFO - ✗ Model rejected: PICP=94.94% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.01}
# 2025-08-24 03:45:31,072 - INFO - ✗ Model rejected: PICP=73.42% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 03:45:31,564 - INFO - ✗ Model rejected: PICP=92.41% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 03:45:32,049 - INFO - ✓ Valid model found: PICP=98.73%, MPIW=30.0649, CRPS=23.9600 with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.01}
# 2025-08-24 03:45:32,499 - INFO - ✗ Model rejected: PICP=77.22% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 03:45:32,976 - INFO - ✓ Valid model found: PICP=97.47%, MPIW=167.6256, CRPS=157.0316 with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 03:45:33,404 - INFO - ✓ Valid model found: PICP=97.47%, MPIW=19.4509, CRPS=13.4890 with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.01}
# 2025-08-24 03:45:33,990 - INFO - ✗ Model rejected: PICP=74.68% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 03:45:34,497 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=43.5801, CRPS=18.5456 with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 03:45:34,930 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=27.7852, CRPS=17.0760 with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.01}
# 2025-08-24 03:45:35,365 - INFO - ✗ Model rejected: PICP=75.95% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 03:45:35,830 - INFO - ✗ Model rejected: PICP=84.81% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 03:45:36,291 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=28.5549, CRPS=19.3309 with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.01}
# 2025-08-24 03:45:36,785 - INFO - ✗ Model rejected: PICP=64.56% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 03:45:37,287 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=52.9506, CRPS=15.5441 with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 03:45:37,790 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=44.8271, CRPS=13.6137 with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.01}
# 2025-08-24 03:45:38,271 - INFO - ✗ Model rejected: PICP=48.10% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 03:45:38,724 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=59.1786, CRPS=24.3735 with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 03:45:39,184 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=36.8005, CRPS=22.4730 with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.01}
# 2025-08-24 03:45:39,657 - INFO - ✗ Model rejected: PICP=77.22% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 03:45:40,142 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=35.2909, CRPS=25.6326 with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 03:45:40,619 - INFO - ✗ Model rejected: PICP=94.94% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.01}
# 2025-08-24 03:45:41,141 - INFO - ✗ Model rejected: PICP=49.37% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 03:45:41,605 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=61.2654, CRPS=28.1957 with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 03:45:42,127 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=35.4682, CRPS=23.0695 with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.01}
# 2025-08-24 03:45:42,683 - INFO - ✗ Model rejected: PICP=83.54% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 03:45:43,256 - INFO - ✗ Model rejected: PICP=84.81% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 03:45:43,825 - INFO - ✗ Model rejected: PICP=93.67% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.01}
# 2025-08-24 03:45:44,356 - INFO - ✗ Model rejected: PICP=79.75% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 03:45:44,864 - INFO - ✗ Model rejected: PICP=93.67% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 03:45:45,431 - INFO - ✗ Model rejected: PICP=93.67% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.01}
# 2025-08-24 03:45:46,024 - INFO - ✗ Model rejected: PICP=77.22% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 03:45:46,634 - INFO - ✗ Model rejected: PICP=89.87% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 03:45:47,185 - INFO - ✗ Model rejected: PICP=74.68% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.01}
# 2025-08-24 03:45:47,707 - INFO - ✗ Model rejected: PICP=73.42% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 03:45:48,273 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=165.7344, CRPS=150.3401 with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 03:45:48,818 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=27.3181, CRPS=18.5007 with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.01}
# 2025-08-24 03:45:49,403 - INFO - ✗ Model rejected: PICP=81.01% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 03:45:49,957 - INFO - ✓ Valid model found: PICP=97.47%, MPIW=194.9115, CRPS=184.0980 with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 03:45:50,474 - INFO - ✗ Model rejected: PICP=93.67% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.01}
# 2025-08-24 03:45:51,069 - INFO - ✗ Model rejected: PICP=74.68% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 03:45:51,593 - INFO - ✗ Model rejected: PICP=94.94% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 03:45:52,181 - INFO - ✗ Model rejected: PICP=93.67% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.01}
# 2025-08-24 03:45:52,612 - INFO - ✗ Model rejected: PICP=72.15% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 03:45:52,998 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=121.8139, CRPS=54.7184 with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 03:45:53,505 - INFO - ✓ Valid model found: PICP=98.73%, MPIW=20.6695, CRPS=13.6476 with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.01}
# 2025-08-24 03:45:53,990 - INFO - ✗ Model rejected: PICP=82.28% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 03:45:54,439 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=114.0919, CRPS=95.0870 with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 03:45:54,969 - INFO - ✗ Model rejected: PICP=93.67% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.01}
# 2025-08-24 03:45:55,505 - INFO - ✗ Model rejected: PICP=74.68% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 03:45:56,095 - INFO - ✗ Model rejected: PICP=74.68% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 03:45:56,642 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=24.2304, CRPS=15.0582 with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.01}
# 2025-08-24 03:45:57,136 - INFO - ✗ Model rejected: PICP=62.03% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 03:45:57,687 - INFO - ✓ Valid model found: PICP=96.20%, MPIW=187.1913, CRPS=176.2194 with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 03:45:58,197 - INFO - ✓ Valid model found: PICP=98.73%, MPIW=23.2667, CRPS=14.6744 with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.01}
# 2025-08-24 03:45:58,756 - INFO - ✗ Model rejected: PICP=69.62% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 03:45:59,306 - INFO - ✓ Valid model found: PICP=97.47%, MPIW=221.7837, CRPS=209.6252 with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 03:45:59,876 - INFO - ✗ Model rejected: PICP=92.41% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.01}
# 2025-08-24 03:46:00,424 - INFO - ✗ Model rejected: PICP=70.89% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 03:46:01,038 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=261.5981, CRPS=243.1450 with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 03:46:01,582 - INFO - ✗ Model rejected: PICP=86.08% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.01}
# 2025-08-24 03:46:02,193 - INFO - ✗ Model rejected: PICP=65.82% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 03:46:02,780 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=53.6674, CRPS=27.4559 with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 03:46:03,328 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=47.4519, CRPS=24.2696 with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.01}
# 2025-08-24 03:46:03,897 - INFO - ✗ Model rejected: PICP=92.41% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 03:46:04,428 - INFO - ✗ Model rejected: PICP=86.08% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 03:46:04,952 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=44.4455, CRPS=24.1370 with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.01}
# 2025-08-24 03:46:05,500 - INFO - ✗ Model rejected: PICP=56.96% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 03:46:06,019 - INFO - ✗ Model rejected: PICP=91.14% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 03:46:06,596 - INFO - ✗ Model rejected: PICP=93.67% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.01}
# 2025-08-24 03:46:07,124 - INFO - ✗ Model rejected: PICP=44.30% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 03:46:07,633 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=60.1905, CRPS=31.4435 with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 03:46:08,190 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=43.9283, CRPS=23.5029 with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.01}
# 2025-08-24 03:46:08,729 - INFO - ✗ Model rejected: PICP=64.56% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 03:46:09,221 - INFO - ✓ Valid model found: PICP=96.20%, MPIW=62.8451, CRPS=54.6738 with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 03:46:09,775 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=53.2732, CRPS=35.5804 with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.01}
# 2025-08-24 03:46:10,332 - INFO - ✗ Model rejected: PICP=91.14% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 03:46:10,820 - INFO - ✗ Model rejected: PICP=92.41% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 03:46:11,281 - INFO - ✗ Model rejected: PICP=94.94% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.01}
# 2025-08-24 03:46:11,775 - INFO - ✗ Model rejected: PICP=75.95% with params {'seq_len': 5, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 03:46:12,209 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=50.5708, CRPS=16.7044 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 03:46:12,722 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=22.1249, CRPS=13.4316 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.01}
# 2025-08-24 03:46:13,197 - INFO - ✗ Model rejected: PICP=81.01% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 03:46:13,708 - INFO - ✗ Model rejected: PICP=81.01% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 03:46:14,226 - INFO - ✗ Model rejected: PICP=89.87% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.01}
# 2025-08-24 03:46:14,706 - INFO - ✗ Model rejected: PICP=81.01% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 03:46:15,199 - INFO - ✗ Model rejected: PICP=93.67% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 03:46:15,622 - INFO - ✗ Model rejected: PICP=92.41% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.01}
# 2025-08-24 03:46:16,179 - INFO - ✗ Model rejected: PICP=74.68% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 03:46:16,627 - INFO - ✓ Valid model found: PICP=98.73%, MPIW=101.4199, CRPS=92.6669 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 03:46:17,138 - INFO - ✓ Valid model found: PICP=97.47%, MPIW=18.4580, CRPS=9.4907 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.01}
# 2025-08-24 03:46:17,647 - INFO - ✗ Model rejected: PICP=79.75% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 03:46:18,121 - INFO - ✓ Valid model found: PICP=97.47%, MPIW=142.3811, CRPS=131.4296 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 03:46:18,591 - INFO - ✓ Valid model found: PICP=98.73%, MPIW=23.4253, CRPS=15.7808 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.01}
# 2025-08-24 03:46:19,096 - INFO - ✗ Model rejected: PICP=81.01% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 03:46:19,596 - INFO - ✗ Model rejected: PICP=92.41% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 03:46:20,063 - INFO - ✓ Valid model found: PICP=97.47%, MPIW=25.9402, CRPS=19.4500 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.01}
# 2025-08-24 03:46:20,496 - INFO - ✗ Model rejected: PICP=81.01% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 03:46:21,026 - INFO - ✗ Model rejected: PICP=93.67% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 03:46:21,510 - INFO - ✓ Valid model found: PICP=97.47%, MPIW=16.6366, CRPS=7.8193 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.01}
# 2025-08-24 03:46:21,979 - INFO - ✗ Model rejected: PICP=72.15% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 03:46:22,436 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=225.6257, CRPS=190.1098 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 03:46:22,990 - INFO - ✓ Valid model found: PICP=96.20%, MPIW=14.0099, CRPS=7.6010 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.01}
# 2025-08-24 03:46:23,460 - INFO - ✗ Model rejected: PICP=70.89% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 03:46:23,926 - INFO - ✗ Model rejected: PICP=89.87% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 03:46:24,435 - INFO - ✗ Model rejected: PICP=93.67% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.01}
# 2025-08-24 03:46:24,916 - INFO - ✗ Model rejected: PICP=70.89% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 03:46:25,411 - INFO - ✓ Valid model found: PICP=98.73%, MPIW=91.4220, CRPS=82.6954 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 03:46:25,952 - INFO - ✓ Valid model found: PICP=97.47%, MPIW=17.9541, CRPS=8.6013 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.01}
# 2025-08-24 03:46:26,442 - INFO - ✗ Model rejected: PICP=79.75% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 03:46:26,932 - INFO - ✗ Model rejected: PICP=93.67% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 03:46:27,444 - INFO - ✓ Valid model found: PICP=97.47%, MPIW=13.9809, CRPS=8.1978 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.01}
# 2025-08-24 03:46:27,914 - INFO - ✗ Model rejected: PICP=78.48% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 03:46:28,381 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=242.8374, CRPS=224.2321 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 03:46:28,890 - INFO - ✓ Valid model found: PICP=98.73%, MPIW=25.2162, CRPS=19.2588 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.01}
# 2025-08-24 03:46:29,346 - INFO - ✗ Model rejected: PICP=81.01% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 03:46:29,812 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=37.5097, CRPS=18.6677 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 03:46:30,320 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=26.9565, CRPS=17.9543 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.01}
# 2025-08-24 03:46:30,830 - INFO - ✗ Model rejected: PICP=93.67% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 03:46:31,332 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=48.3647, CRPS=40.7855 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 03:46:31,812 - INFO - ✗ Model rejected: PICP=88.61% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.01}
# 2025-08-24 03:46:32,331 - INFO - ✗ Model rejected: PICP=83.54% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 03:46:32,838 - INFO - ✗ Model rejected: PICP=92.41% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 03:46:33,330 - INFO - ✗ Model rejected: PICP=93.67% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.01}
# 2025-08-24 03:46:33,862 - INFO - ✗ Model rejected: PICP=54.43% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 03:46:34,363 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=40.0595, CRPS=21.6743 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 03:46:34,833 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=40.4904, CRPS=16.5445 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.01}
# 2025-08-24 03:46:35,302 - INFO - ✗ Model rejected: PICP=74.68% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 03:46:35,798 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=55.4850, CRPS=25.5608 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 03:46:36,254 - INFO - ✓ Valid model found: PICP=98.73%, MPIW=40.4661, CRPS=32.9909 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.01}
# 2025-08-24 03:46:36,767 - INFO - ✗ Model rejected: PICP=73.42% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 03:46:37,287 - INFO - ✗ Model rejected: PICP=87.34% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 03:46:37,794 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=41.9911, CRPS=21.2930 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.01}
# 2025-08-24 03:46:38,300 - INFO - ✗ Model rejected: PICP=84.81% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 03:46:38,838 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=162.1176, CRPS=113.4293 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 03:46:39,451 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=19.7526, CRPS=10.8670 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.01}
# 2025-08-24 03:46:40,034 - INFO - ✗ Model rejected: PICP=73.42% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 03:46:40,622 - INFO - ✗ Model rejected: PICP=77.22% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 03:46:41,163 - INFO - ✗ Model rejected: PICP=94.94% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.01}
# 2025-08-24 03:46:41,732 - INFO - ✗ Model rejected: PICP=64.56% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 03:46:42,305 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=150.7911, CRPS=136.2967 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 03:46:42,893 - INFO - ✗ Model rejected: PICP=93.67% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.01}
# 2025-08-24 03:46:43,492 - INFO - ✗ Model rejected: PICP=59.49% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 03:46:44,061 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=264.2450, CRPS=223.0560 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 03:46:44,610 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=32.8747, CRPS=25.3224 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.01}
# 2025-08-24 03:46:45,221 - INFO - ✗ Model rejected: PICP=72.15% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 03:46:45,795 - INFO - ✗ Model rejected: PICP=81.01% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 03:46:46,219 - INFO - ✓ Valid model found: PICP=96.20%, MPIW=35.0837, CRPS=28.7363 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.01}
# 2025-08-24 03:46:46,703 - INFO - ✗ Model rejected: PICP=69.62% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 03:46:47,280 - INFO - ✗ Model rejected: PICP=60.76% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 03:46:48,355 - INFO - ✗ Model rejected: PICP=77.22% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.01}
# 2025-08-24 03:46:48,927 - INFO - ✗ Model rejected: PICP=65.82% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 03:46:49,491 - INFO - ✓ Valid model found: PICP=96.20%, MPIW=51.9481, CRPS=42.0597 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 03:46:50,088 - INFO - ✓ Valid model found: PICP=96.20%, MPIW=25.6865, CRPS=11.4187 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.01}
# 2025-08-24 03:46:50,660 - INFO - ✗ Model rejected: PICP=58.23% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 03:46:51,287 - INFO - ✗ Model rejected: PICP=94.94% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 03:46:51,853 - INFO - ✓ Valid model found: PICP=98.73%, MPIW=17.3497, CRPS=8.3860 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.01}
# 2025-08-24 03:46:52,506 - INFO - ✗ Model rejected: PICP=73.42% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 03:46:53,085 - INFO - ✗ Model rejected: PICP=82.28% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 03:46:53,644 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=70.4483, CRPS=60.0249 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.01}
# 2025-08-24 03:46:54,260 - INFO - ✗ Model rejected: PICP=56.96% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 03:46:54,816 - INFO - ✓ Valid model found: PICP=98.73%, MPIW=276.4533, CRPS=263.5042 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 03:46:55,415 - INFO - ✓ Valid model found: PICP=97.47%, MPIW=16.3425, CRPS=9.0953 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.01}
# 2025-08-24 03:46:56,003 - INFO - ✗ Model rejected: PICP=74.68% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 03:46:56,591 - INFO - ✗ Model rejected: PICP=88.61% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 03:46:57,156 - INFO - ✓ Valid model found: PICP=96.20%, MPIW=29.9727, CRPS=19.3323 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.01}
# 2025-08-24 03:46:57,790 - INFO - ✗ Model rejected: PICP=65.82% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 03:46:58,367 - INFO - ✗ Model rejected: PICP=94.94% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 03:46:58,913 - INFO - ✗ Model rejected: PICP=93.67% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.01}
# 2025-08-24 03:46:59,457 - INFO - ✗ Model rejected: PICP=59.49% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 03:47:00,015 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=45.1457, CRPS=22.1048 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 03:47:00,588 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=32.5393, CRPS=21.0923 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.01}
# 2025-08-24 03:47:01,110 - INFO - ✗ Model rejected: PICP=93.67% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 03:47:01,565 - INFO - ✗ Model rejected: PICP=89.87% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 03:47:02,034 - INFO - ✗ Model rejected: PICP=94.94% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.01}
# 2025-08-24 03:47:02,559 - INFO - ✗ Model rejected: PICP=91.14% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 03:47:03,123 - INFO - ✗ Model rejected: PICP=93.67% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 03:47:03,708 - INFO - ✗ Model rejected: PICP=94.94% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.01}
# 2025-08-24 03:47:04,266 - INFO - ✗ Model rejected: PICP=84.81% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 03:47:04,871 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=56.9860, CRPS=25.3814 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 03:47:05,429 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=44.1999, CRPS=23.4956 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.01}
# 2025-08-24 03:47:06,003 - INFO - ✓ Valid model found: PICP=96.20%, MPIW=18.4375, CRPS=12.5423 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 03:47:06,596 - INFO - ✗ Model rejected: PICP=93.67% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 03:47:07,181 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=48.6907, CRPS=25.9678 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.01}
# 2025-08-24 03:47:07,754 - INFO - ✗ Model rejected: PICP=88.61% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 03:47:08,335 - INFO - ✗ Model rejected: PICP=94.94% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 03:47:08,922 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=38.2292, CRPS=22.2872 with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.01}
# 2025-08-24 03:47:09,456 - INFO - ✗ Model rejected: PICP=89.87% with params {'seq_len': 5, 'hidden_dim': 48, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 03:47:09,966 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=39.3142, CRPS=13.8715 with params {'seq_len': 5, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 03:47:10,461 - INFO - ✓ Valid model found: PICP=96.20%, MPIW=16.7869, CRPS=7.7268 with params {'seq_len': 5, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.01}
# 2025-08-24 03:47:11,070 - INFO - ✗ Model rejected: PICP=81.01% with params {'seq_len': 5, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 03:47:12,094 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=189.7936, CRPS=166.2126 with params {'seq_len': 5, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 03:47:12,527 - INFO - ✓ Valid model found: PICP=97.47%, MPIW=19.3172, CRPS=13.1899 with params {'seq_len': 5, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.01}
# 2025-08-24 03:47:13,050 - INFO - ✗ Model rejected: PICP=79.75% with params {'seq_len': 5, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 03:47:13,697 - INFO - ✗ Model rejected: PICP=93.67% with params {'seq_len': 5, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 03:47:14,339 - INFO - ✓ Valid model found: PICP=98.73%, MPIW=22.6482, CRPS=15.7781 with params {'seq_len': 5, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.01}
# 2025-08-24 03:47:14,917 - INFO - ✗ Model rejected: PICP=77.22% with params {'seq_len': 5, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# ...
# 2025-08-24 04:23:02,604 - INFO - ✗ Model rejected: PICP=81.48% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 04:23:03,544 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=37.2844, CRPS=18.1127 with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 04:23:05,056 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=24.9975, CRPS=16.6238 with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.01}
# 2025-08-24 04:23:06,562 - INFO - ✗ Model rejected: PICP=92.59% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 04:23:07,480 - INFO - ✗ Model rejected: PICP=83.33% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 04:23:08,926 - INFO - ✓ Valid model found: PICP=96.30%, MPIW=22.5870, CRPS=17.5726 with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.01}
# 2025-08-24 04:23:10,500 - INFO - ✗ Model rejected: PICP=83.33% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 04:23:11,507 - INFO - ✗ Model rejected: PICP=87.04% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 04:23:12,943 - INFO - ✗ Model rejected: PICP=94.44% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.01}
# 2025-08-24 04:23:14,524 - INFO - ✗ Model rejected: PICP=79.63% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 04:23:15,465 - INFO - ✗ Model rejected: PICP=88.89% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 04:23:16,905 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=27.0042, CRPS=18.9726 with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.01}
# 2025-08-24 04:23:17,912 - INFO - ✗ Model rejected: PICP=90.74% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 04:23:19,378 - INFO - ✗ Model rejected: PICP=83.33% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 04:23:20,833 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=28.5927, CRPS=20.8728 with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.01}
# 2025-08-24 04:23:21,837 - INFO - ✗ Model rejected: PICP=83.33% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 04:23:23,281 - INFO - ✗ Model rejected: PICP=87.04% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 04:23:24,838 - INFO - ✗ Model rejected: PICP=90.74% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.01}
# 2025-08-24 04:23:25,765 - INFO - ✗ Model rejected: PICP=81.48% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 04:23:27,973 - INFO - ✗ Model rejected: PICP=79.63% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 04:23:30,716 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=16.8678, CRPS=7.0954 with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.01}
# 2025-08-24 04:23:32,956 - INFO - ✗ Model rejected: PICP=77.78% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 04:23:35,145 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=146.3132, CRPS=134.8974 with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 04:23:37,199 - INFO - ✓ Valid model found: PICP=96.30%, MPIW=22.2798, CRPS=16.7915 with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.01}
# 2025-08-24 04:23:39,513 - INFO - ✗ Model rejected: PICP=81.48% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 04:23:41,711 - INFO - ✗ Model rejected: PICP=68.52% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 04:23:43,745 - INFO - ✗ Model rejected: PICP=81.48% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.01}
# 2025-08-24 04:23:46,650 - INFO - ✗ Model rejected: PICP=55.56% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 04:23:48,827 - INFO - ✗ Model rejected: PICP=20.37% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 04:23:51,006 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=18.6680, CRPS=11.3285 with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.01}
# 2025-08-24 04:23:53,228 - INFO - ✗ Model rejected: PICP=79.63% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 04:23:55,571 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=272.3717, CRPS=254.5418 with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 04:23:58,122 - INFO - ✗ Model rejected: PICP=72.22% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.01}
# 2025-08-24 04:24:01,061 - INFO - ✗ Model rejected: PICP=81.48% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 04:24:03,176 - INFO - ✗ Model rejected: PICP=94.44% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 04:24:05,393 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=37.2285, CRPS=30.2362 with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.01}
# 2025-08-24 04:24:07,640 - INFO - ✗ Model rejected: PICP=75.93% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 04:24:10,202 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=181.4480, CRPS=170.9231 with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 04:24:12,416 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=24.6427, CRPS=15.0480 with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.01}
# 2025-08-24 04:24:15,311 - INFO - ✗ Model rejected: PICP=79.63% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 04:24:17,535 - INFO - ✗ Model rejected: PICP=75.93% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 04:24:19,824 - INFO - ✓ Valid model found: PICP=96.30%, MPIW=23.6082, CRPS=18.3301 with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.01}
# 2025-08-24 04:24:22,178 - INFO - ✗ Model rejected: PICP=77.78% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 04:24:24,597 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=417.6286, CRPS=375.9615 with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 04:24:27,513 - INFO - ✗ Model rejected: PICP=92.59% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.01}
# 2025-08-24 04:24:29,750 - INFO - ✗ Model rejected: PICP=66.67% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 04:24:31,909 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=496.9758, CRPS=470.0284 with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 04:24:34,043 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=25.0833, CRPS=12.6851 with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.01}
# 2025-08-24 04:24:36,198 - INFO - ✗ Model rejected: PICP=85.19% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 04:24:38,444 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=203.0842, CRPS=190.8879 with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 04:24:40,684 - INFO - ✗ Model rejected: PICP=92.59% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.01}
# 2025-08-24 04:24:43,092 - INFO - ✗ Model rejected: PICP=90.74% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 04:24:45,347 - INFO - ✗ Model rejected: PICP=27.78% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 04:24:48,239 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=26.7383, CRPS=19.4572 with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.01}
# 2025-08-24 04:24:50,436 - INFO - ✗ Model rejected: PICP=75.93% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 04:24:52,636 - INFO - ✗ Model rejected: PICP=85.19% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 04:24:54,752 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=28.6217, CRPS=19.7230 with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.01}
# 2025-08-24 04:24:57,002 - INFO - ✗ Model rejected: PICP=77.78% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 04:24:59,436 - INFO - ✗ Model rejected: PICP=85.19% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 04:25:01,943 - INFO - ✗ Model rejected: PICP=83.33% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.01}
# 2025-08-24 04:25:04,092 - INFO - ✗ Model rejected: PICP=70.37% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 04:25:06,957 - INFO - ✗ Model rejected: PICP=85.19% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 04:25:09,240 - INFO - ✗ Model rejected: PICP=83.33% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.01}
# 2025-08-24 04:25:11,534 - INFO - ✗ Model rejected: PICP=70.37% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 04:25:13,803 - INFO - ✗ Model rejected: PICP=75.93% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 04:25:16,332 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=32.6453, CRPS=24.2776 with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.01}
# 2025-08-24 04:25:18,658 - INFO - ✗ Model rejected: PICP=79.63% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 04:25:21,491 - INFO - ✗ Model rejected: PICP=87.04% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 04:25:23,700 - INFO - ✗ Model rejected: PICP=94.44% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.01}
# 2025-08-24 04:25:25,865 - INFO - ✗ Model rejected: PICP=74.07% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 04:25:28,195 - INFO - ✗ Model rejected: PICP=83.33% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 04:25:30,639 - INFO - ✗ Model rejected: PICP=87.04% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.01}
# 2025-08-24 04:25:32,830 - INFO - ✗ Model rejected: PICP=68.52% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.97, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 04:25:32,831 - INFO - Training final model on combined train+validation data...
# 2025-08-24 04:25:34,541 - INFO - Evaluating final model on the test set...
# 2025-08-24 04:25:34,702 - INFO - Final Model Performance on Test Set
# 2025-08-24 04:25:34,704 - INFO - Generating final plot...
# ========================================
# ========================================
# Best Hyperparameters: {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# Prediction Interval Coverage (PICP): 96.61%
# Mean Prediction Interval Width (MPIW): 12.0173
# Continuous Ranked Probability Score (CRPS): 8.8911
# ========================================

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import itertools
import logging

# torch.manual_seed(42)
# np.random.seed(42)

# --- 1. Configuration ---
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

CONFIG = {
    "file_path": r"C:\Users\DAIICT I\Desktop\Msc DS Sujal 202418017\Interval_Forecast_Normal\df_without_exo.xlsx",
    "target_col": "Carbon_Price_USD",
    "original_features": ['Carbon_Price_USD'],
    
    # --- Splitting Logic ---
    "test_split_date": '2024-04-01',
    "val_ratio_of_train_data": 0.1,
    
    "target_coverage": 95.0,
    "device": torch.device("cuda" if torch.cuda.is_available() else "cpu"),
    
    "param_grid": {
        'seq_len': [1, 2, 3, 4, 5, 10, 15, 20, 25, 30],
        'hidden_dim': [32, 64, 96],
        'num_layers': [1, 2],
        'learning_rate': [0.005, 0.01, 0.001],
        'epochs': [100],
        'q': [0.95],
        'r': [0.4, 0.5, 0.6],
        'delta': [0.0, 0.1]
    }
}

# --- 2. Model Definition & Loss Function ---

class LSTMTube(nn.Module):
    """LSTM model designed to output two values for the prediction interval."""
    def __init__(self, input_dim, hidden_dim=64, num_layers=1):
        super().__init__()
        # CHANGED: Use nn.LSTM instead of nn.RNN
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True)
        # The final layer still outputs 2 values
        self.fc = nn.Linear(hidden_dim, 2)

    def forward(self, x):
        out, _ = self.lstm(x)
        return self.fc(out[:, -1, :])

def confidence_loss(y_pred, y_true, q, r, delta):
    # This loss function remains the same
    y_true = y_true.squeeze(-1)
    f2 = y_pred[:, 0]
    f1 = y_pred[:, 1]
    crossover_penalty = torch.mean(torch.relu(f1 - f2))
    c1 = (1 - q) * (f2 - y_true)
    c2 = (1 - q) * (y_true - f1)
    c3 = q * (f1 - y_true)
    c4 = q * (y_true - f2)
    loss_part1 = torch.where(y_true > r * (f1 + f2), c1, c2)
    loss_part2 = torch.where(f1 > y_true, c3, c4)
    is_inside = torch.logical_and(y_true <= f2, y_true >= f1)
    width_penalty = delta * torch.abs(f1 - f2)
    final_loss = torch.where(is_inside, loss_part1, loss_part2) + width_penalty
    return torch.mean(final_loss) + crossover_penalty

def crps_score(y_true, pred_lower, pred_upper):
    """
    Calculates the CRPS for a quantile-based forecast.
    This is an approximation based on the two quantiles.
    
    Args:
        y_true (np.array): The true values.
        pred_lower (np.array): The lower quantile predictions (e.g., 2.5th).
        pred_upper (np.array): The upper quantile predictions (e.g., 97.5th).

    Returns:
        float: The average CRPS score.
    """
    alpha = 0.05  # For a 95% interval (1 - alpha)
    
    # This is an approximation of CRPS for quantile forecasts.
    # It penalizes being outside the interval and also accounts for wide intervals.
    crps = np.mean(
        (y_true - pred_lower) * ((y_true > pred_lower) - (1 - alpha / 2)) +
        (pred_upper - y_true) * ((y_true < pred_upper) - (alpha / 2))
    )
    return crps

# --- 3. Pipeline Functions ---

def load_and_clean_data(file_path):
    # This function remains the same
    logging.info(f"Loading data from {file_path}...")
    df = pd.read_excel(file_path) 
    df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)
    df.sort_values('Date', inplace=True)
    if pd.api.types.is_object_dtype(df['Vol.']):
        def convert_volume(vol):
            try:
                if isinstance(vol, str):
                    vol = vol.replace('K', '*1e3').replace('M', '*1e6')
                    return eval(vol)
                return np.nan
            except: return np.nan
        df['Vol.'] = df['Vol.'].apply(convert_volume)
    df['Vol.'] = pd.to_numeric(df['Vol.'], errors='coerce')
    df['Change %'] = pd.to_numeric(df['Change %'], errors='coerce')
    df.set_index('Date', inplace=True)
    return df

def engineer_features(df, original_features, target_col):
    # This function remains the same
    logging.info("Engineering lagged features...")
    for feature in original_features:
        df[f'{feature}_lag1'] = df[feature].shift(1)
    feature_cols = [f'{col}_lag1' for col in original_features]
    df.dropna(inplace=True)
    if df.empty:
        raise ValueError("DataFrame is empty after feature engineering.")
    X = df[feature_cols]
    y = df[[target_col]]
    return X, y

def split_and_scale_data(X, y, test_split_date, val_ratio):
    # This function remains the same
    logging.info(f"Splitting test data at date: {test_split_date}")
    test_split_date = pd.to_datetime(test_split_date)
    train_val_mask = X.index < test_split_date
    X_train_val, X_test = X[train_val_mask], X[~train_val_mask]
    y_train_val, y_test = y[train_val_mask], y[~train_val_mask]
    val_split_index = int(len(X_train_val) * (1 - val_ratio))
    X_train, X_val = X_train_val[:val_split_index], X_train_val[val_split_index:]
    y_train, y_val = y_train_val[:val_split_index], y_train_val[val_split_index:]
    logging.info(f"Train size: {len(X_train)}, Validation size: {len(X_val)}, Test size: {len(X_test)}")
    if len(X_train) == 0 or len(X_val) == 0 or len(X_test) == 0:
         raise ValueError("One of the data splits is empty.")
    scaler_X = MinMaxScaler()
    scaler_y = MinMaxScaler()
    X_train_scaled = scaler_X.fit_transform(X_train)
    y_train_scaled = scaler_y.fit_transform(y_train)
    X_val_scaled = scaler_X.transform(X_val)
    y_val_scaled = scaler_y.transform(y_val)
    X_test_scaled = scaler_X.transform(X_test)
    y_test_scaled = scaler_y.transform(y_test)
    return (X_train_scaled, y_train_scaled, X_val_scaled, y_val_scaled, 
            X_test_scaled, y_test_scaled, scaler_y)

def create_sequences(X, y, seq_len):
    # This function remains the same
    X_seq, y_seq = [], []
    for i in range(seq_len, len(X)):
        X_seq.append(X[i - seq_len:i])
        y_seq.append(y[i])
    return np.array(X_seq), np.array(y_seq)

def train_tube_model(X_train, y_train, params):
    """Trains a single LSTM Tube model."""
    # CHANGED: Instantiate LSTMTube instead of RNNTube
    model = LSTMTube(
        X_train.shape[2], 
        params['hidden_dim'], 
        params['num_layers']
    ).to(CONFIG['device'])
    
    optimizer = torch.optim.Adam(model.parameters(), lr=params['learning_rate'])
    X_train_t = torch.tensor(X_train, dtype=torch.float32).to(CONFIG['device'])
    y_train_t = torch.tensor(y_train, dtype=torch.float32).to(CONFIG['device'])
    q, r, delta = params['q'], params['r'], params['delta']

    for _ in range(params['epochs']):
        model.train()
        optimizer.zero_grad()
        y_pred = model(X_train_t)
        loss = confidence_loss(y_pred, y_train_t, q, r, delta)
        loss.backward()
        optimizer.step()
    return model

def find_best_hyperparameters(train_data, val_data, param_grid, scaler_y):
    # This function is modified to use CRPS for model selection
    X_train_scaled, y_train_scaled = train_data
    X_val_scaled, y_val_scaled = val_data
    valid_models = []
    param_combinations = list(itertools.product(*param_grid.values()))
    logging.info(f"Starting hyperparameter search over {len(param_combinations)} combinations...")

    for values in param_combinations:
        params = dict(zip(param_grid.keys(), values))
        X_train_seq, y_train_seq = create_sequences(X_train_scaled, y_train_scaled, params['seq_len'])
        X_val_seq, y_val_seq = create_sequences(X_val_scaled, y_val_scaled, params['seq_len'])
        if len(X_val_seq) == 0: continue
        model = train_tube_model(X_train_seq, y_train_seq, params)
        X_val_t = torch.tensor(X_val_seq, dtype=torch.float32).to(CONFIG['device'])
        with torch.no_grad():
            predictions = model(X_val_t).cpu().numpy()
        pred_upper_s = predictions[:, 0:1]
        pred_lower_s = predictions[:, 1:2]
        pred_lower = scaler_y.inverse_transform(pred_lower_s).flatten()
        pred_upper = scaler_y.inverse_transform(pred_upper_s).flatten()
        y_val_true = scaler_y.inverse_transform(y_val_seq).flatten()
        pred_lower, pred_upper = np.minimum(pred_lower, pred_upper), np.maximum(pred_lower, pred_upper)
        picp = np.mean((y_val_true >= pred_lower) & (y_val_true <= pred_upper)) * 100
        mpiw = np.mean(pred_upper - pred_lower)
        crps = crps_score(y_val_true, pred_lower, pred_upper)
        if picp >= CONFIG['target_coverage']:
            logging.info(f"✓ Valid model found: PICP={picp:.2f}%, MPIW={mpiw:.4f}, CRPS={crps:.4f} with params {params}")
            valid_models.append({'mpiw': mpiw, 'crps': crps, 'params': params})
        else:
            logging.info(f"✗ Model rejected: PICP={picp:.2f}% with params {params}")
    if not valid_models:
        raise ValueError("No valid hyperparameters found that meet the PICP threshold.")
    best_model_info = min(valid_models, key=lambda x: x['crps'])
    return best_model_info['params']

def evaluate_on_test_set(best_params, train_val_data, test_data, scaler_y):
    # This function is modified to include CRPS in the final results
    X_train_val_scaled, y_train_val_scaled = train_val_data
    X_test_scaled, y_test_scaled = test_data
    logging.info("Training final model on combined train+validation data...")
    X_train_val_seq, y_train_val_seq = create_sequences(X_train_val_scaled, y_train_val_scaled, best_params['seq_len'])
    X_test_seq, y_test_seq = create_sequences(X_test_scaled, y_test_scaled, best_params['seq_len'])
    model = train_tube_model(X_train_val_seq, y_train_val_seq, best_params)
    logging.info("Evaluating final model on the test set...")
    X_test_t = torch.tensor(X_test_seq, dtype=torch.float32).to(CONFIG['device'])
    with torch.no_grad():
        predictions = model(X_test_t).cpu().numpy()
    pred_upper_s = predictions[:, 0:1]
    pred_lower_s = predictions[:, 1:2]
    pred_lower = scaler_y.inverse_transform(pred_lower_s).flatten()
    pred_upper = scaler_y.inverse_transform(pred_upper_s).flatten()
    y_test_true = scaler_y.inverse_transform(y_test_seq).flatten()
    pred_lower, pred_upper = np.minimum(pred_lower, pred_upper), np.maximum(pred_lower, pred_upper)
    final_picp = np.mean((y_test_true >= pred_lower) & (y_test_true <= pred_upper)) * 100
    final_mpiw = np.mean(pred_upper - pred_lower)
    final_crps = crps_score(y_test_true, pred_lower, pred_upper)
    results = {"picp": final_picp, "mpiw": final_mpiw, "crps": final_crps}
    plot_data = {"pred_lower": pred_lower, "pred_upper": pred_upper, "y_true": y_test_true}
    return results, plot_data

def plot_results(plot_data, test_dates):
    # This function remains the same
    logging.info("Generating final plot...")
    y_true = plot_data['y_true']
    dates_for_plot = test_dates[-len(y_true):]
    plt.figure(figsize=(15, 7))
    plt.plot(dates_for_plot, y_true, label='Actual Price', color='black', linewidth=1.5)
    plt.fill_between(dates_for_plot, plot_data['pred_lower'], plot_data['pred_upper'], 
                     color='dodgerblue', alpha=0.3, label=f'Prediction Interval')
    plt.title('Final Model Evaluation on Test Set (LSTM+Tube)')
    plt.xlabel('Date')
    plt.ylabel(CONFIG['target_col'])
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.show()

# --- 4. Main Execution ---
def main():
    # This function remains the same
    df = load_and_clean_data(CONFIG['file_path'])
    X, y = engineer_features(df, CONFIG['original_features'], CONFIG['target_col'])
    (X_train_s, y_train_s, X_val_s, y_val_s, 
     X_test_s, y_test_s, scaler_y) = split_and_scale_data(
         X, y, 
         test_split_date=CONFIG['test_split_date'], 
         val_ratio=CONFIG['val_ratio_of_train_data']
    )
    best_params = find_best_hyperparameters(
        train_data=(X_train_s, y_train_s),
        val_data=(X_val_s, y_val_s),
        param_grid=CONFIG['param_grid'],
        scaler_y=scaler_y
    )
    X_train_val_s = np.concatenate((X_train_s, X_val_s), axis=0)
    y_train_val_s = np.concatenate((y_train_s, y_val_s), axis=0)
    final_results, plot_data = evaluate_on_test_set(
        best_params=best_params,
        train_val_data=(X_train_val_s, y_train_val_s),
        test_data=(X_test_s, y_test_s),
        scaler_y=scaler_y
    )
    print("\n" + "="*40)
    logging.info("Final Model Performance on Test Set")
    print("="*40)
    print(f"Best Hyperparameters: {best_params}")
    print(f"Prediction Interval Coverage (PICP): {final_results['picp']:.2f}%")
    print(f"Mean Prediction Interval Width (MPIW): {final_results['mpiw']:.4f}")
    print(f"Continuous Ranked Probability Score (CRPS): {final_results['crps']:.4f}")
    print("="*40 + "\n")
    test_dates_index = X[X.index >= pd.to_datetime(CONFIG['test_split_date'])].index
    plot_results(plot_data, test_dates=test_dates_index)

if __name__ == "__main__":
    main()
# Out:
# 2025-08-24 20:28:22,207 - INFO - Loading data from C:\Users\DAIICT I\Desktop\Msc DS Sujal 202418017\Interval_Forecast_Normal\df_without_exo.xlsx...
# 2025-08-24 20:28:22,309 - INFO - Engineering lagged features...
# 2025-08-24 20:28:22,310 - INFO - Splitting test data at date: 2024-04-01
# 2025-08-24 20:28:22,312 - INFO - Train size: 750, Validation size: 84, Test size: 89
# 2025-08-24 20:28:22,314 - INFO - Starting hyperparameter search over 1080 combinations...
# 2025-08-24 20:28:23,383 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=43.6485, CRPS=22.7034 with params {'seq_len': 1, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:28:23,549 - INFO - ✗ Model rejected: PICP=83.13% with params {'seq_len': 1, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:28:23,708 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=51.3467, CRPS=22.3775 with params {'seq_len': 1, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:28:23,871 - INFO - ✗ Model rejected: PICP=86.75% with params {'seq_len': 1, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:28:24,031 - INFO - ✗ Model rejected: PICP=92.77% with params {'seq_len': 1, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:28:24,180 - INFO - ✗ Model rejected: PICP=77.11% with params {'seq_len': 1, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:28:24,329 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=50.1848, CRPS=24.2578 with params {'seq_len': 1, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:28:24,489 - INFO - ✓ Valid model found: PICP=97.59%, MPIW=14.2966, CRPS=10.1720 with params {'seq_len': 1, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:28:24,646 - INFO - ✗ Model rejected: PICP=91.57% with params {'seq_len': 1, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:28:24,806 - INFO - ✗ Model rejected: PICP=85.54% with params {'seq_len': 1, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:28:24,973 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=90.1706, CRPS=79.0660 with params {'seq_len': 1, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:28:25,138 - INFO - ✗ Model rejected: PICP=79.52% with params {'seq_len': 1, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:28:25,280 - INFO - ✗ Model rejected: PICP=24.10% with params {'seq_len': 1, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:28:25,433 - INFO - ✗ Model rejected: PICP=92.77% with params {'seq_len': 1, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:28:25,587 - INFO - ✓ Valid model found: PICP=95.18%, MPIW=43.0115, CRPS=13.7858 with params {'seq_len': 1, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:28:25,746 - INFO - ✗ Model rejected: PICP=75.90% with params {'seq_len': 1, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:28:25,889 - INFO - ✗ Model rejected: PICP=45.78% with params {'seq_len': 1, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:28:26,041 - INFO - ✗ Model rejected: PICP=87.95% with params {'seq_len': 1, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:28:26,220 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=54.2504, CRPS=28.8185 with params {'seq_len': 1, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:28:26,396 - INFO - ✗ Model rejected: PICP=83.13% with params {'seq_len': 1, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:28:26,567 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=55.2885, CRPS=29.6034 with params {'seq_len': 1, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:28:26,750 - INFO - ✗ Model rejected: PICP=83.13% with params {'seq_len': 1, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:28:26,928 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=97.8152, CRPS=79.5482 with params {'seq_len': 1, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:28:27,100 - INFO - ✓ Valid model found: PICP=98.80%, MPIW=15.5945, CRPS=10.4298 with params {'seq_len': 1, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:28:27,267 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=57.8019, CRPS=29.8638 with params {'seq_len': 1, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:28:27,437 - INFO - ✓ Valid model found: PICP=96.39%, MPIW=13.3431, CRPS=6.5961 with params {'seq_len': 1, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:28:27,607 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=147.8903, CRPS=133.3686 with params {'seq_len': 1, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:28:27,782 - INFO - ✗ Model rejected: PICP=93.98% with params {'seq_len': 1, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:28:27,957 - INFO - ✓ Valid model found: PICP=98.80%, MPIW=133.7469, CRPS=125.1334 with params {'seq_len': 1, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:28:28,126 - INFO - ✗ Model rejected: PICP=73.49% with params {'seq_len': 1, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:28:28,300 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=69.0796, CRPS=31.1812 with params {'seq_len': 1, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:28:28,464 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=45.9142, CRPS=27.3478 with params {'seq_len': 1, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:28:28,653 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=61.3977, CRPS=33.7507 with params {'seq_len': 1, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:28:28,814 - INFO - ✗ Model rejected: PICP=92.77% with params {'seq_len': 1, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:28:28,987 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=66.3266, CRPS=27.4267 with params {'seq_len': 1, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:28:29,167 - INFO - ✗ Model rejected: PICP=80.72% with params {'seq_len': 1, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:28:29,336 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=39.0155, CRPS=24.0588 with params {'seq_len': 1, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:28:29,500 - INFO - ✗ Model rejected: PICP=90.36% with params {'seq_len': 1, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:28:29,653 - INFO - ✓ Valid model found: PICP=98.80%, MPIW=71.1750, CRPS=64.7916 with params {'seq_len': 1, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:28:29,831 - INFO - ✗ Model rejected: PICP=79.52% with params {'seq_len': 1, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:28:29,993 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=44.8601, CRPS=21.7941 with params {'seq_len': 1, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:28:30,160 - INFO - ✗ Model rejected: PICP=80.72% with params {'seq_len': 1, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:28:30,317 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=52.6089, CRPS=24.5220 with params {'seq_len': 1, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:28:30,473 - INFO - ✗ Model rejected: PICP=69.88% with params {'seq_len': 1, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:28:30,641 - INFO - ✓ Valid model found: PICP=98.80%, MPIW=119.8185, CRPS=113.1606 with params {'seq_len': 1, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:28:30,804 - INFO - ✗ Model rejected: PICP=81.93% with params {'seq_len': 1, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:28:30,958 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=106.2428, CRPS=97.9328 with params {'seq_len': 1, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:28:31,119 - INFO - ✗ Model rejected: PICP=73.49% with params {'seq_len': 1, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:28:31,285 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=59.1077, CRPS=21.1980 with params {'seq_len': 1, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:28:31,455 - INFO - ✗ Model rejected: PICP=84.34% with params {'seq_len': 1, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:28:31,616 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=52.4107, CRPS=24.0611 with params {'seq_len': 1, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:28:31,784 - INFO - ✗ Model rejected: PICP=75.90% with params {'seq_len': 1, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:28:31,946 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=50.9588, CRPS=22.3180 with params {'seq_len': 1, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:28:32,109 - INFO - ✗ Model rejected: PICP=75.90% with params {'seq_len': 1, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:28:32,313 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=57.1329, CRPS=28.3436 with params {'seq_len': 1, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:28:32,507 - INFO - ✓ Valid model found: PICP=96.39%, MPIW=15.5539, CRPS=5.4926 with params {'seq_len': 1, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:28:32,709 - INFO - ✓ Valid model found: PICP=98.80%, MPIW=152.8131, CRPS=144.2199 with params {'seq_len': 1, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:28:32,908 - INFO - ✗ Model rejected: PICP=89.16% with params {'seq_len': 1, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:28:33,123 - INFO - ✓ Valid model found: PICP=98.80%, MPIW=168.1322, CRPS=159.8589 with params {'seq_len': 1, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:28:33,323 - INFO - ✗ Model rejected: PICP=89.16% with params {'seq_len': 1, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:28:33,535 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=151.9796, CRPS=127.9513 with params {'seq_len': 1, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:28:33,727 - INFO - ✗ Model rejected: PICP=56.63% with params {'seq_len': 1, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:28:33,937 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=207.1828, CRPS=192.9747 with params {'seq_len': 1, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:28:34,139 - INFO - ✗ Model rejected: PICP=71.08% with params {'seq_len': 1, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:28:34,353 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=212.9626, CRPS=168.8874 with params {'seq_len': 1, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:28:34,557 - INFO - ✗ Model rejected: PICP=73.49% with params {'seq_len': 1, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:28:34,761 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=57.2240, CRPS=29.0810 with params {'seq_len': 1, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:28:34,975 - INFO - ✗ Model rejected: PICP=80.72% with params {'seq_len': 1, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:28:35,173 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=60.6778, CRPS=34.0384 with params {'seq_len': 1, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:28:35,385 - INFO - ✗ Model rejected: PICP=81.93% with params {'seq_len': 1, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:28:35,566 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=60.3246, CRPS=37.1719 with params {'seq_len': 1, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:28:35,774 - INFO - ✗ Model rejected: PICP=71.08% with params {'seq_len': 1, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:28:35,965 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=52.8449, CRPS=24.5276 with params {'seq_len': 1, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:28:36,155 - INFO - ✗ Model rejected: PICP=85.54% with params {'seq_len': 1, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:28:36,355 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=75.9837, CRPS=64.2486 with params {'seq_len': 1, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:28:36,550 - INFO - ✗ Model rejected: PICP=78.31% with params {'seq_len': 1, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:28:36,731 - INFO - ✗ Model rejected: PICP=92.77% with params {'seq_len': 1, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:28:36,923 - INFO - ✗ Model rejected: PICP=84.34% with params {'seq_len': 1, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:28:37,134 - INFO - ✓ Valid model found: PICP=98.80%, MPIW=109.4245, CRPS=102.8898 with params {'seq_len': 1, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:28:37,336 - INFO - ✗ Model rejected: PICP=63.86% with params {'seq_len': 1, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:28:37,527 - INFO - ✓ Valid model found: PICP=98.80%, MPIW=144.8840, CRPS=137.5556 with params {'seq_len': 1, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:28:37,723 - INFO - ✗ Model rejected: PICP=73.49% with params {'seq_len': 1, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:28:37,922 - INFO - ✓ Valid model found: PICP=96.39%, MPIW=136.1328, CRPS=129.1705 with params {'seq_len': 1, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:28:38,125 - INFO - ✗ Model rejected: PICP=68.67% with params {'seq_len': 1, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:28:38,313 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=55.7158, CRPS=26.9462 with params {'seq_len': 1, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:28:38,505 - INFO - ✗ Model rejected: PICP=90.36% with params {'seq_len': 1, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:28:38,705 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=56.2636, CRPS=27.9314 with params {'seq_len': 1, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:28:38,917 - INFO - ✗ Model rejected: PICP=84.34% with params {'seq_len': 1, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:28:39,096 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=55.1770, CRPS=28.1640 with params {'seq_len': 1, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:28:39,300 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=41.4809, CRPS=21.4966 with params {'seq_len': 1, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:28:39,556 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=146.3158, CRPS=135.6331 with params {'seq_len': 1, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:28:39,830 - INFO - ✓ Valid model found: PICP=96.39%, MPIW=9.9054, CRPS=5.8938 with params {'seq_len': 1, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:28:40,075 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=172.6491, CRPS=162.7425 with params {'seq_len': 1, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:28:40,343 - INFO - ✗ Model rejected: PICP=90.36% with params {'seq_len': 1, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:28:40,616 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=152.0006, CRPS=137.2592 with params {'seq_len': 1, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:28:40,859 - INFO - ✗ Model rejected: PICP=78.31% with params {'seq_len': 1, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:28:41,106 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=150.2039, CRPS=117.2724 with params {'seq_len': 1, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:28:41,372 - INFO - ✗ Model rejected: PICP=67.47% with params {'seq_len': 1, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:28:41,634 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=249.2422, CRPS=236.4465 with params {'seq_len': 1, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:28:41,878 - INFO - ✗ Model rejected: PICP=60.24% with params {'seq_len': 1, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:28:42,137 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=231.1056, CRPS=219.2893 with params {'seq_len': 1, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:28:42,388 - INFO - ✗ Model rejected: PICP=63.86% with params {'seq_len': 1, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:28:42,642 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=54.0658, CRPS=26.4777 with params {'seq_len': 1, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:28:42,901 - INFO - ✗ Model rejected: PICP=85.54% with params {'seq_len': 1, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:28:43,160 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=54.7291, CRPS=28.3653 with params {'seq_len': 1, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:28:43,397 - INFO - ✗ Model rejected: PICP=84.34% with params {'seq_len': 1, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:28:43,670 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=66.7559, CRPS=47.2297 with params {'seq_len': 1, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:28:43,936 - INFO - ✗ Model rejected: PICP=75.90% with params {'seq_len': 1, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:28:44,110 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=52.1750, CRPS=23.6250 with params {'seq_len': 2, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:28:44,281 - INFO - ✓ Valid model found: PICP=98.78%, MPIW=17.6761, CRPS=11.3569 with params {'seq_len': 2, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:28:44,452 - INFO - ✓ Valid model found: PICP=97.56%, MPIW=84.0807, CRPS=77.6128 with params {'seq_len': 2, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:28:44,611 - INFO - ✓ Valid model found: PICP=95.12%, MPIW=15.4800, CRPS=10.5817 with params {'seq_len': 2, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:28:44,787 - INFO - ✓ Valid model found: PICP=95.12%, MPIW=90.5382, CRPS=84.4194 with params {'seq_len': 2, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:28:44,961 - INFO - ✗ Model rejected: PICP=81.71% with params {'seq_len': 2, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:28:45,125 - INFO - ✓ Valid model found: PICP=95.12%, MPIW=150.6372, CRPS=142.8618 with params {'seq_len': 2, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:28:45,272 - INFO - ✗ Model rejected: PICP=81.71% with params {'seq_len': 2, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:28:45,446 - INFO - ✓ Valid model found: PICP=95.12%, MPIW=157.0484, CRPS=149.1908 with params {'seq_len': 2, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:28:45,626 - INFO - ✗ Model rejected: PICP=79.27% with params {'seq_len': 2, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:28:45,784 - INFO - ✓ Valid model found: PICP=97.56%, MPIW=93.6774, CRPS=87.0502 with params {'seq_len': 2, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:28:45,958 - INFO - ✗ Model rejected: PICP=71.95% with params {'seq_len': 2, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:28:46,110 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=54.3274, CRPS=27.9813 with params {'seq_len': 2, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:28:46,281 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=46.4783, CRPS=21.4046 with params {'seq_len': 2, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:28:46,457 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=57.6958, CRPS=26.7268 with params {'seq_len': 2, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:28:46,628 - INFO - ✗ Model rejected: PICP=87.80% with params {'seq_len': 2, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:28:46,798 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=58.5141, CRPS=29.9930 with params {'seq_len': 2, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:28:46,947 - INFO - ✗ Model rejected: PICP=79.27% with params {'seq_len': 2, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:28:47,127 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=55.9413, CRPS=28.6983 with params {'seq_len': 2, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:28:47,327 - INFO - ✓ Valid model found: PICP=95.12%, MPIW=12.6313, CRPS=5.4657 with params {'seq_len': 2, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:28:47,525 - INFO - ✗ Model rejected: PICP=90.24% with params {'seq_len': 2, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:28:47,726 - INFO - ✗ Model rejected: PICP=85.37% with params {'seq_len': 2, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:28:47,896 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=133.1676, CRPS=122.3256 with params {'seq_len': 2, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:28:48,078 - INFO - ✗ Model rejected: PICP=80.49% with params {'seq_len': 2, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:28:48,276 - INFO - ✗ Model rejected: PICP=92.68% with params {'seq_len': 2, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:28:48,467 - INFO - ✗ Model rejected: PICP=64.63% with params {'seq_len': 2, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:28:48,655 - INFO - ✗ Model rejected: PICP=93.90% with params {'seq_len': 2, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:28:48,830 - INFO - ✗ Model rejected: PICP=60.98% with params {'seq_len': 2, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:28:49,014 - INFO - ✗ Model rejected: PICP=86.59% with params {'seq_len': 2, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:28:49,190 - INFO - ✗ Model rejected: PICP=54.88% with params {'seq_len': 2, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:28:49,373 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=58.5293, CRPS=30.3579 with params {'seq_len': 2, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:28:49,572 - INFO - ✗ Model rejected: PICP=84.15% with params {'seq_len': 2, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:28:49,765 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=66.2423, CRPS=37.4231 with params {'seq_len': 2, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:28:49,966 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=36.4641, CRPS=21.9555 with params {'seq_len': 2, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:28:50,158 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=61.4255, CRPS=34.7029 with params {'seq_len': 2, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:28:50,332 - INFO - ✗ Model rejected: PICP=92.68% with params {'seq_len': 2, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:28:50,513 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=31.7135, CRPS=24.0916 with params {'seq_len': 2, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:28:50,703 - INFO - ✗ Model rejected: PICP=93.90% with params {'seq_len': 2, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:28:50,890 - INFO - ✓ Valid model found: PICP=97.56%, MPIW=131.4291, CRPS=123.8808 with params {'seq_len': 2, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:28:51,072 - INFO - ✗ Model rejected: PICP=79.27% with params {'seq_len': 2, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:28:51,247 - INFO - ✗ Model rejected: PICP=92.68% with params {'seq_len': 2, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:28:51,416 - INFO - ✗ Model rejected: PICP=80.49% with params {'seq_len': 2, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:28:51,598 - INFO - ✗ Model rejected: PICP=92.68% with params {'seq_len': 2, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:28:51,788 - INFO - ✗ Model rejected: PICP=70.73% with params {'seq_len': 2, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:28:51,986 - INFO - ✓ Valid model found: PICP=97.56%, MPIW=151.6309, CRPS=143.5474 with params {'seq_len': 2, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:28:52,162 - INFO - ✗ Model rejected: PICP=67.07% with params {'seq_len': 2, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:28:52,327 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=194.9111, CRPS=184.3077 with params {'seq_len': 2, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:28:52,515 - INFO - ✗ Model rejected: PICP=68.29% with params {'seq_len': 2, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:28:52,699 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=64.5309, CRPS=29.7064 with params {'seq_len': 2, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:28:52,891 - INFO - ✗ Model rejected: PICP=78.05% with params {'seq_len': 2, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:28:53,071 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=67.8903, CRPS=29.4184 with params {'seq_len': 2, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:28:53,238 - INFO - ✗ Model rejected: PICP=76.83% with params {'seq_len': 2, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:28:53,420 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=59.5955, CRPS=30.5254 with params {'seq_len': 2, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:28:53,598 - INFO - ✗ Model rejected: PICP=73.17% with params {'seq_len': 2, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:28:53,839 - INFO - ✓ Valid model found: PICP=97.56%, MPIW=196.4675, CRPS=187.3340 with params {'seq_len': 2, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:28:54,058 - INFO - ✗ Model rejected: PICP=64.63% with params {'seq_len': 2, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:28:54,250 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=234.7101, CRPS=200.1962 with params {'seq_len': 2, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:28:54,426 - INFO - ✗ Model rejected: PICP=71.95% with params {'seq_len': 2, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:28:54,609 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=222.0899, CRPS=211.3013 with params {'seq_len': 2, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:28:54,804 - INFO - ✗ Model rejected: PICP=60.98% with params {'seq_len': 2, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:28:54,972 - INFO - ✗ Model rejected: PICP=90.24% with params {'seq_len': 2, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:28:55,158 - INFO - ✗ Model rejected: PICP=62.20% with params {'seq_len': 2, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:28:55,343 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=157.0894, CRPS=142.7690 with params {'seq_len': 2, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:28:55,533 - INFO - ✗ Model rejected: PICP=65.85% with params {'seq_len': 2, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:28:55,726 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=371.9610, CRPS=356.0832 with params {'seq_len': 2, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:28:55,900 - INFO - ✗ Model rejected: PICP=64.63% with params {'seq_len': 2, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:28:56,094 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=51.6987, CRPS=23.2037 with params {'seq_len': 2, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:28:56,286 - INFO - ✗ Model rejected: PICP=86.59% with params {'seq_len': 2, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:28:56,459 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=59.8313, CRPS=32.6561 with params {'seq_len': 2, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:28:56,639 - INFO - ✗ Model rejected: PICP=76.83% with params {'seq_len': 2, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:28:56,810 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=80.9066, CRPS=63.3624 with params {'seq_len': 2, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:28:56,993 - INFO - ✗ Model rejected: PICP=75.61% with params {'seq_len': 2, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:28:57,165 - INFO - ✗ Model rejected: PICP=90.24% with params {'seq_len': 2, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:28:57,332 - INFO - ✗ Model rejected: PICP=71.95% with params {'seq_len': 2, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:28:57,514 - INFO - ✓ Valid model found: PICP=97.56%, MPIW=168.0203, CRPS=159.2932 with params {'seq_len': 2, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:28:57,692 - INFO - ✗ Model rejected: PICP=79.27% with params {'seq_len': 2, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:28:57,864 - INFO - ✗ Model rejected: PICP=91.46% with params {'seq_len': 2, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:28:58,044 - INFO - ✗ Model rejected: PICP=75.61% with params {'seq_len': 2, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:28:58,224 - INFO - ✓ Valid model found: PICP=96.34%, MPIW=208.2093, CRPS=198.8631 with params {'seq_len': 2, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:28:58,404 - INFO - ✗ Model rejected: PICP=70.73% with params {'seq_len': 2, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:28:58,588 - INFO - ✗ Model rejected: PICP=90.24% with params {'seq_len': 2, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:28:58,772 - INFO - ✗ Model rejected: PICP=67.07% with params {'seq_len': 2, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:28:58,958 - INFO - ✓ Valid model found: PICP=97.56%, MPIW=238.9129, CRPS=228.5754 with params {'seq_len': 2, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:28:59,134 - INFO - ✗ Model rejected: PICP=64.63% with params {'seq_len': 2, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:28:59,310 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=65.3852, CRPS=28.9198 with params {'seq_len': 2, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:28:59,492 - INFO - ✗ Model rejected: PICP=87.80% with params {'seq_len': 2, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:28:59,672 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=50.3898, CRPS=27.1335 with params {'seq_len': 2, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:28:59,854 - INFO - ✗ Model rejected: PICP=86.59% with params {'seq_len': 2, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:29:00,028 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=53.3606, CRPS=29.8314 with params {'seq_len': 2, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:29:00,205 - INFO - ✗ Model rejected: PICP=79.27% with params {'seq_len': 2, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:29:00,445 - INFO - ✓ Valid model found: PICP=96.34%, MPIW=172.6917, CRPS=164.3324 with params {'seq_len': 2, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:29:00,691 - INFO - ✗ Model rejected: PICP=70.73% with params {'seq_len': 2, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:29:00,926 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=256.8215, CRPS=244.7125 with params {'seq_len': 2, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:29:01,168 - INFO - ✗ Model rejected: PICP=67.07% with params {'seq_len': 2, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:29:01,385 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=299.0854, CRPS=275.6684 with params {'seq_len': 2, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:29:01,633 - INFO - ✗ Model rejected: PICP=65.85% with params {'seq_len': 2, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:29:01,861 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=287.9528, CRPS=274.4204 with params {'seq_len': 2, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:29:02,106 - INFO - ✗ Model rejected: PICP=65.85% with params {'seq_len': 2, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:29:02,326 - INFO - ✗ Model rejected: PICP=80.49% with params {'seq_len': 2, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:29:02,590 - INFO - ✗ Model rejected: PICP=62.20% with params {'seq_len': 2, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:29:02,828 - INFO - ✗ Model rejected: PICP=89.02% with params {'seq_len': 2, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:29:03,087 - INFO - ✗ Model rejected: PICP=65.85% with params {'seq_len': 2, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:29:03,299 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=57.2684, CRPS=29.4755 with params {'seq_len': 2, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:29:03,538 - INFO - ✗ Model rejected: PICP=85.37% with params {'seq_len': 2, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:29:03,759 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=54.4490, CRPS=26.1125 with params {'seq_len': 2, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:29:04,003 - INFO - ✗ Model rejected: PICP=81.71% with params {'seq_len': 2, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:29:04,241 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=99.7241, CRPS=80.4913 with params {'seq_len': 2, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:29:04,484 - INFO - ✗ Model rejected: PICP=73.17% with params {'seq_len': 2, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:29:04,630 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=43.9341, CRPS=25.5280 with params {'seq_len': 3, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:29:04,775 - INFO - ✗ Model rejected: PICP=90.12% with params {'seq_len': 3, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:29:04,917 - INFO - ✓ Valid model found: PICP=97.53%, MPIW=133.3507, CRPS=125.3559 with params {'seq_len': 3, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:29:05,063 - INFO - ✗ Model rejected: PICP=80.25% with params {'seq_len': 3, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:29:05,206 - INFO - ✗ Model rejected: PICP=93.83% with params {'seq_len': 3, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:29:05,349 - INFO - ✗ Model rejected: PICP=77.78% with params {'seq_len': 3, 'hidden_dim': 32, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# ...
# 2025-08-24 20:32:22,703 - INFO - ✗ Model rejected: PICP=92.59% with params {'seq_len': 30, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:32:22,851 - INFO - ✗ Model rejected: PICP=92.59% with params {'seq_len': 30, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:32:22,994 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=245.5566, CRPS=226.6082 with params {'seq_len': 30, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:32:23,136 - INFO - ✗ Model rejected: PICP=77.78% with params {'seq_len': 30, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:32:23,279 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=263.0961, CRPS=242.7728 with params {'seq_len': 30, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:32:23,426 - INFO - ✗ Model rejected: PICP=70.37% with params {'seq_len': 30, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:32:23,570 - INFO - ✗ Model rejected: PICP=40.74% with params {'seq_len': 30, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:32:23,708 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=13.7678, CRPS=8.6343 with params {'seq_len': 30, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:32:23,852 - INFO - ✗ Model rejected: PICP=90.74% with params {'seq_len': 30, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:32:24,004 - INFO - ✗ Model rejected: PICP=79.63% with params {'seq_len': 30, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:32:24,146 - INFO - ✗ Model rejected: PICP=92.59% with params {'seq_len': 30, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:32:24,290 - INFO - ✗ Model rejected: PICP=57.41% with params {'seq_len': 30, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:32:24,433 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=52.9268, CRPS=30.5446 with params {'seq_len': 30, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:32:24,575 - INFO - ✗ Model rejected: PICP=70.37% with params {'seq_len': 30, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:32:24,716 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=98.7612, CRPS=85.9799 with params {'seq_len': 30, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:32:24,871 - INFO - ✗ Model rejected: PICP=59.26% with params {'seq_len': 30, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:32:25,022 - INFO - ✗ Model rejected: PICP=38.89% with params {'seq_len': 30, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:32:25,173 - INFO - ✗ Model rejected: PICP=62.96% with params {'seq_len': 30, 'hidden_dim': 64, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:32:25,362 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=177.5296, CRPS=165.4359 with params {'seq_len': 30, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:32:25,560 - INFO - ✗ Model rejected: PICP=59.26% with params {'seq_len': 30, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:32:25,764 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=53.8177, CRPS=36.2184 with params {'seq_len': 30, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:32:25,955 - INFO - ✗ Model rejected: PICP=59.26% with params {'seq_len': 30, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:32:26,158 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=317.5037, CRPS=276.9994 with params {'seq_len': 30, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:32:26,355 - INFO - ✗ Model rejected: PICP=61.11% with params {'seq_len': 30, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:32:26,543 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=60.2944, CRPS=16.5123 with params {'seq_len': 30, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:32:26,741 - INFO - ✗ Model rejected: PICP=64.81% with params {'seq_len': 30, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:32:26,942 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=282.1057, CRPS=264.2111 with params {'seq_len': 30, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:32:27,132 - INFO - ✗ Model rejected: PICP=72.22% with params {'seq_len': 30, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:32:27,332 - INFO - ✗ Model rejected: PICP=75.93% with params {'seq_len': 30, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:32:27,530 - INFO - ✗ Model rejected: PICP=62.96% with params {'seq_len': 30, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:32:27,722 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=52.0597, CRPS=33.7152 with params {'seq_len': 30, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:32:27,916 - INFO - ✗ Model rejected: PICP=70.37% with params {'seq_len': 30, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:32:28,120 - INFO - ✗ Model rejected: PICP=72.22% with params {'seq_len': 30, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:32:28,311 - INFO - ✗ Model rejected: PICP=64.81% with params {'seq_len': 30, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:32:28,516 - INFO - ✓ Valid model found: PICP=98.15%, MPIW=172.1506, CRPS=159.0234 with params {'seq_len': 30, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:32:28,720 - INFO - ✗ Model rejected: PICP=57.41% with params {'seq_len': 30, 'hidden_dim': 64, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:32:28,911 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=41.6799, CRPS=23.4843 with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:32:29,106 - INFO - ✗ Model rejected: PICP=72.22% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:32:29,305 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=74.3417, CRPS=24.3157 with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:32:29,497 - INFO - ✗ Model rejected: PICP=79.63% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:32:29,691 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=119.9179, CRPS=109.9294 with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:32:29,891 - INFO - ✗ Model rejected: PICP=74.07% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:32:30,078 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=42.2883, CRPS=23.5192 with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:32:30,271 - INFO - ✗ Model rejected: PICP=85.19% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:32:30,472 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=29.9238, CRPS=18.3453 with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:32:30,656 - INFO - ✗ Model rejected: PICP=66.67% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:32:30,852 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=87.7958, CRPS=26.5790 with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:32:31,048 - INFO - ✗ Model rejected: PICP=94.44% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:32:31,240 - INFO - ✗ Model rejected: PICP=83.33% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:32:31,437 - INFO - ✗ Model rejected: PICP=74.07% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:32:31,635 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=124.3120, CRPS=110.0980 with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:32:31,834 - INFO - ✗ Model rejected: PICP=74.07% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:32:32,031 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=189.1553, CRPS=174.1037 with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:32:32,229 - INFO - ✗ Model rejected: PICP=77.78% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 1, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:32:32,524 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=402.6111, CRPS=383.4194 with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:32:32,818 - INFO - ✗ Model rejected: PICP=72.22% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:32:33,111 - INFO - ✗ Model rejected: PICP=72.22% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:32:33,408 - INFO - ✗ Model rejected: PICP=74.07% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:32:33,711 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=33.6637, CRPS=25.4103 with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:32:34,006 - INFO - ✗ Model rejected: PICP=61.11% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:32:34,306 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=444.7679, CRPS=421.3556 with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:32:34,594 - INFO - ✗ Model rejected: PICP=68.52% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:32:34,887 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=292.4590, CRPS=273.1477 with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:32:35,175 - INFO - ✗ Model rejected: PICP=72.22% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:32:35,475 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=495.4955, CRPS=471.5931 with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:32:35,771 - INFO - ✗ Model rejected: PICP=66.67% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.01, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:32:36,100 - INFO - ✗ Model rejected: PICP=59.26% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.0}
# 2025-08-24 20:32:36,425 - INFO - ✗ Model rejected: PICP=72.22% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# 2025-08-24 20:32:36,745 - INFO - ✓ Valid model found: PICP=100.00%, MPIW=183.4636, CRPS=170.6819 with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.0}
# 2025-08-24 20:32:37,067 - INFO - ✗ Model rejected: PICP=64.81% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.5, 'delta': 0.1}
# 2025-08-24 20:32:37,397 - INFO - ✗ Model rejected: PICP=70.37% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.0}
# 2025-08-24 20:32:37,714 - INFO - ✗ Model rejected: PICP=61.11% with params {'seq_len': 30, 'hidden_dim': 96, 'num_layers': 2, 'learning_rate': 0.001, 'epochs': 100, 'q': 0.95, 'r': 0.6, 'delta': 0.1}
# 2025-08-24 20:32:37,715 - INFO - Training final model on combined train+validation data...
# 2025-08-24 20:32:37,869 - INFO - Evaluating final model on the test set...
# 2025-08-24 20:32:37,871 - INFO - Final Model Performance on Test Set
# 2025-08-24 20:32:37,872 - INFO - Generating final plot...
# ========================================
# ========================================
# Best Hyperparameters: {'seq_len': 2, 'hidden_dim': 32, 'num_layers': 2, 'learning_rate': 0.005, 'epochs': 100, 'q': 0.95, 'r': 0.4, 'delta': 0.1}
# Prediction Interval Coverage (PICP): 95.40%
# Mean Prediction Interval Width (MPIW): 12.3961
# Continuous Ranked Probability Score (CRPS): 5.1758
# ========================================
